# %% [markdown]
# https://www.spe.org/datasets/dataset_1/

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Данные по скважинам

# %%
well_data = pd.read_csv('well_data.csv', index_col='Lease').transpose(); well_data
# Out:
# Lease         Well Number State Formation/Reservoir  \
# OSPREY                  1    TX          EAGLE FORD
# FALCON                  2    TX          EAGLE FORD
# HAWK                    3    TX          EAGLE FORD
# EAGLE                   4    TX          EAGLE FORD
# KITE                    5    TX          EAGLE FORD
# SWIFT                   6    TX          EAGLE FORD
# SPARROW                 7    TX          EAGLE FORD
# LARK                    8    TX          EAGLE FORD
# CARDINAL                9    TX          EAGLE FORD
# JAY                    10    TX          EAGLE FORD
# CROW                   11    TX          EAGLE FORD
# LORIKEET               62    LA   HAYNESVILLE SHALE
# MYNAH                  63    LA   HAYNESVILLE SHALE
# PARTRIDGE              64    LA   HAYNESVILLE SHALE
# CASSOWARY              65    LA   HAYNESVILLE SHALE
# ORIOLE                 66    LA   HAYNESVILLE SHALE
# WARBLER                67    LA   HAYNESVILLE SHALE
# HARPY                  68    LA   HAYNESVILLE SHALE
# BEE-EATER              69    LA   HAYNESVILLE SHALE
# LOON                   70    LA   HAYNESVILLE SHALE
# CUCKOO                 71    LA      BOSSIER SHALE
# ROOSTER                72    LA   HAYNESVILLE SHALE
# ARCHAEOPTERYX          73    LA   HAYNESVILLE SHALE
# TERN                   74    LA   HAYNESVILLE SHALE
# STILT                  75    LA   HAYNESVILLE SHALE
# AVOCET                 76    LA   HAYNESVILLE SHALE
# OSTRICH                23    PA           MARCELLUS
# EMU                    24    PA           MARCELLUS
# DUCK                   25    PA           MARCELLUS
# HERON                  26    PA           MARCELLUS
# STORK                  27    PA           MARCELLUS
# SWAN                   28    PA           MARCELLUS
# PARROT                 29    PA           MARCELLUS
# CRANE                  30    PA           MARCELLUS
# IBIS                   31    PA           MARCELLUS
# EGRET                  32    PA           MARCELLUS
# PHEASANT               33    PA           MARCELLUS
# MACAW                  34    PA   MARCELLUS - UPPER
# FLAMINGO               35    PA   MARCELLUS - UPPER
# PEACOCK                36    PA   MARCELLUS - UPPER
# PENGUIN                37    PA   MARCELLUS - UPPER
# ALBATROSS              38    PA   MARCELLUS - UPPER
# PELICAN                39    PA   MARCELLUS - UPPER
# OWL                    40    PA   MARCELLUS - UPPER
# FINCH                  41    PA   MARCELLUS - UPPER
# ROBIN                  42    PA   MARCELLUS - UPPER
# BLUEBIRD               43    PA   MARCELLUS - UPPER
# CANARY                 44    PA   MARCELLUS - UPPER
# SEAGULL                45    PA   MARCELLUS - UPPER
# HUMMINGBIRD            46    PA   MARCELLUS - UPPER
# PHOENIX                47    PA   MARCELLUS - UPPER
# TOUCAN                 48    PA   MARCELLUS - UPPER
# GOOSE                  49    PA   MARCELLUS - UPPER
#
# Lease          Initial Pressure Estimate (psi)   \
# OSPREY                                     5400
# FALCON                                     5700
# HAWK                                       5650
# EAGLE                                      5000
# KITE                                       5000
# SWIFT                                      5164
# SPARROW                                    5164
# LARK                                       5700
# CARDINAL                                   5900
# JAY                                        5700
# CROW                                       5500
# LORIKEET                                   9939
# MYNAH                                      9800
# PARTRIDGE                                  9900
# CASSOWARY                                 12223
# ORIOLE                                    11325
# WARBLER                                   11000
# HARPY                                     11325
# BEE-EATER                                 10000
# LOON                                      10000
# CUCKOO                                    10500
# ROOSTER                                   10500
# ARCHAEOPTERYX                             10300
# TERN                                      10450
# STILT                                     10800
# AVOCET                                    11000
# OSTRICH                                    3486
# EMU                                        5531
# DUCK                                       3900
# HERON                                      3500
# STORK                                      3000
# SWAN                                       4500
# PARROT                                     4750
# CRANE                                      5538
# IBIS                                       5508
# EGRET                                      5227
# PHEASANT                                   4450
# MACAW                                      4609
# FLAMINGO                                   4500
# PEACOCK                                    3150
# PENGUIN                                    3400
# ALBATROSS                                  5000
# PELICAN                                    2500
# OWL                                        2200
# FINCH                                      4300
# ROBIN                                      4100
# BLUEBIRD                                   4200
# CANARY                                     4300
# SEAGULL                                    4400
# HUMMINGBIRD                                4000
# PHOENIX                                    4450
# TOUCAN                                     3900
# GOOSE                                      5200
#
# Lease          Reservoir Temperature (deg F)   Net Pay (ft)   \
# OSPREY                                    225             78
# FALCON                                    225             66
# HAWK                                      225             67
# EAGLE                                     235             74
# KITE                                      238             56
# SWIFT                                     225             63
# SPARROW                                   225             62
# LARK                                      228             68
# CARDINAL                                  228             67
# JAY                                       228             67
# CROW                                      221             63
# LORIKEET                                  285            268
# MYNAH                                     351            208
# PARTRIDGE                                 351            209
# CASSOWARY                                 331            161
# ORIOLE                                    343            166
# WARBLER                                   335            166
# HARPY                                     343            166
# BEE-EATER                                 379            165
# LOON                                      379            165
# CUCKOO                                    305            150
# ROOSTER                                   350            180
# ARCHAEOPTERYX                             343            183
# TERN                                      329            193
# STILT                                     346            150
# AVOCET                                    348            150
# OSTRICH                                   115            102
# EMU                                       143            132
# DUCK                                      137            134
# HERON                                     133            150
# STORK                                     133            150
# SWAN                                      134            150
# PARROT                                    135            148
# CRANE                                     146            134
# IBIS                                      146            134
# EGRET                                     134            143
# PHEASANT                                  130            142
# MACAW                                     135            164
# FLAMINGO                                  135            164
# PEACOCK                                   125            231
# PENGUIN                                   125            232
# ALBATROSS                                 126            170
# PELICAN                                   136            245
# OWL                                       136            246
# FINCH                                     133            177
# ROBIN                                     133            177
# BLUEBIRD                                  125            241
# CANARY                                    133            241
# SEAGULL                                   136            230
# HUMMINGBIRD                               136            230
# PHOENIX                                   137            232
# TOUCAN                                    137            232
# GOOSE                                     134            223
#
# Lease          Wellbore Diameter (ft)  Porosity  Water Saturation   \
# OSPREY                             0.7    6.30%             26.00%
# FALCON                             0.7    6.30%             27.00%
# HAWK                               0.7    6.30%             27.10%
# EAGLE                              0.7    6.30%             27.00%
# KITE                               0.7    5.00%             32.10%
# SWIFT                              0.7    5.20%             33.10%
# SPARROW                            0.7    5.20%             33.20%
# LARK                               0.7    5.20%             36.30%
# CARDINAL                           0.7    5.20%             36.00%
# JAY                                0.7    5.20%             36.10%
# CROW                               0.7    5.20%             32.10%
# LORIKEET                           0.7    8.80%             18.38%
# MYNAH                              0.7    8.84%             20.25%
# PARTRIDGE                          0.7    8.84%             20.25%
# CASSOWARY                          0.7    9.10%             19.07%
# ORIOLE                             0.7    8.56%             20.09%
# WARBLER                            0.7    8.55%             20.09%
# HARPY                              0.7    8.56%             20.09%
# BEE-EATER                          0.7    9.10%             20.00%
# LOON                               0.7    9.10%             20.00%
# CUCKOO                             0.7   10.00%             20.00%
# ROOSTER                            0.7    8.00%             20.00%
# ARCHAEOPTERYX                      0.7    8.61%             21.00%
# TERN                               0.7    8.61%             21.00%
# STILT                              0.7    8.39%             22.90%
# AVOCET                             0.7    8.39%             22.90%
# OSTRICH                            0.7    7.00%             32.97%
# EMU                                0.7    6.35%             19.60%
# DUCK                               0.7    6.94%             31.59%
# HERON                              0.7    7.44%             22.94%
# STORK                              0.7    7.49%             21.03%
# SWAN                               0.7    7.11%             31.08%
# PARROT                             0.7    7.08%             30.93%
# CRANE                              0.7    6.36%             34.84%
# IBIS                               0.7    6.37%             34.89%
# EGRET                              0.7    8.11%             43.59%
# PHEASANT                           0.7    7.86%             39.28%
# MACAW                              0.7    6.52%             27.00%
# FLAMINGO                           0.7    6.52%             27.00%
# PEACOCK                            0.7    6.75%             27.00%
# PENGUIN                            0.7    6.72%             26.00%
# ALBATROSS                          0.7    6.39%             38.00%
# PELICAN                            0.7    5.31%             40.00%
# OWL                                0.7    5.29%             39.00%
# FINCH                              0.7    7.23%             41.29%
# ROBIN                              0.7    7.23%             41.28%
# BLUEBIRD                           0.7    6.03%             35.00%
# CANARY                             0.7    6.03%             35.00%
# SEAGULL                            0.7    5.99%             43.00%
# HUMMINGBIRD                        0.7    5.99%             43.00%
# PHOENIX                            0.7    5.87%             47.00%
# TOUCAN                             0.7    5.87%             47.00%
# GOOSE                              0.7    6.17%             40.22%
#
# Lease          Oil Saturation   ... Pressure Loss Correlation  \
# OSPREY                  74.00%  ...             Beggs & Brill
# FALCON                  73.00%  ...                       NaN
# HAWK                    72.90%  ...                       NaN
# EAGLE                   73.00%  ...                       NaN
# KITE                    67.90%  ...                       NaN
# SWIFT                   66.90%  ...                       NaN
# SPARROW                 66.80%  ...                       NaN
# LARK                    63.70%  ...                       NaN
# CARDINAL                64.00%  ...                       NaN
# JAY                     60.20%  ...                       NaN
# CROW                    67.90%  ...                       NaN
# LORIKEET                 0.00%  ...                       NaN
# MYNAH                    0.00%  ...                       NaN
# PARTRIDGE                0.00%  ...                       NaN
# CASSOWARY                0.00%  ...                       NaN
# ORIOLE                   0.00%  ...                       NaN
# WARBLER                  0.00%  ...                       NaN
# HARPY                    0.00%  ...                       NaN
# BEE-EATER                0.00%  ...                       NaN
# LOON                     0.00%  ...                       NaN
# CUCKOO                   0.00%  ...                       NaN
# ROOSTER                  0.00%  ...                       NaN
# ARCHAEOPTERYX            0.00%  ...                       NaN
# TERN                     0.00%  ...                       NaN
# STILT                    0.00%  ...                       NaN
# AVOCET                   0.00%  ...                       NaN
# OSTRICH                  0.13%  ...                       NaN
# EMU                      0.00%  ...                       NaN
# DUCK                     0.00%  ...                       NaN
# HERON                    0.00%  ...                       NaN
# STORK                    0.00%  ...                       NaN
# SWAN                     0.00%  ...                       NaN
# PARROT                   0.00%  ...                       NaN
# CRANE                    0.00%  ...                       NaN
# IBIS                     0.00%  ...                       NaN
# EGRET                    0.00%  ...                       NaN
# PHEASANT                 0.00%  ...                       NaN
# MACAW                    0.00%  ...                       NaN
# FLAMINGO                 0.00%  ...                       NaN
# PEACOCK                  0.00%  ...                       NaN
# PENGUIN                  0.00%  ...                       NaN
# ALBATROSS                0.00%  ...                       NaN
# PELICAN                  0.00%  ...                       NaN
# OWL                      0.00%  ...                       NaN
# FINCH                    0.00%  ...                       NaN
# ROBIN                    0.00%  ...                       NaN
# BLUEBIRD                 0.00%  ...                       NaN
# CANARY                   0.00%  ...                       NaN
# SEAGULL                  0.00%  ...                       NaN
# HUMMINGBIRD              0.00%  ...                       NaN
# PHOENIX                  0.00%  ...                       NaN
# TOUCAN                   0.00%  ...                       NaN
# GOOSE                    0.00%  ...                       NaN
#
# Lease          Tubing ID (in)   Tubing OD (in)   Tubing Depth (ft)   \
# OSPREY                   2.441            2.875                6764
# FALCON                     NaN              NaN                 NaN
# HAWK                       NaN              NaN                 NaN
# EAGLE                      NaN              NaN                 NaN
# KITE                       NaN              NaN                 NaN
# SWIFT                      NaN              NaN                 NaN
# SPARROW                    NaN              NaN                 NaN
# LARK                       NaN              NaN                 NaN
# CARDINAL                   NaN              NaN                 NaN
# JAY                        NaN              NaN                 NaN
# CROW                       NaN              NaN                 NaN
# LORIKEET                   NaN              NaN                 NaN
# MYNAH                      NaN              NaN                 NaN
# PARTRIDGE                  NaN              NaN                 NaN
# CASSOWARY                  NaN              NaN                 NaN
# ORIOLE                     NaN              NaN                 NaN
# WARBLER                    NaN              NaN                 NaN
# HARPY                      NaN              NaN                 NaN
# BEE-EATER                  NaN              NaN                 NaN
# LOON                       NaN              NaN                 NaN
# CUCKOO                     NaN              NaN                 NaN
# ROOSTER                    NaN              NaN                 NaN
# ARCHAEOPTERYX              NaN              NaN                 NaN
# TERN                       NaN              NaN                 NaN
# STILT                      NaN              NaN                 NaN
# AVOCET                     NaN              NaN                 NaN
# OSTRICH                    NaN              NaN                 NaN
# EMU                        NaN              NaN                 NaN
# DUCK                       NaN              NaN                 NaN
# HERON                      NaN              NaN                 NaN
# STORK                      NaN              NaN                 NaN
# SWAN                       NaN              NaN                 NaN
# PARROT                     NaN              NaN                 NaN
# CRANE                      NaN              NaN                 NaN
# IBIS                       NaN              NaN                 NaN
# EGRET                      NaN              NaN                 NaN
# PHEASANT                   NaN              NaN                 NaN
# MACAW                      NaN              NaN                 NaN
# FLAMINGO                   NaN              NaN                 NaN
# PEACOCK                    NaN              NaN                 NaN
# PENGUIN                    NaN              NaN                 NaN
# ALBATROSS                  NaN              NaN                 NaN
# PELICAN                    NaN              NaN                 NaN
# OWL                        NaN              NaN                 NaN
# FINCH                      NaN              NaN                 NaN
# ROBIN                      NaN              NaN                 NaN
# BLUEBIRD                   NaN              NaN                 NaN
# CANARY                     NaN              NaN                 NaN
# SEAGULL                    NaN              NaN                 NaN
# HUMMINGBIRD                NaN              NaN                 NaN
# PHOENIX                    NaN              NaN                 NaN
# TOUCAN                     NaN              NaN                 NaN
# GOOSE                      NaN              NaN                 NaN
#
# Lease          Casing ID 1 (in)   Casing Footage 1 (ft)   Casing ID 2 (in)   \
# OSPREY                      4.67                    6941              2.992
# FALCON                       NaN                     NaN                NaN
# HAWK                         NaN                     NaN                NaN
# EAGLE                        NaN                     NaN                NaN
# KITE                         NaN                     NaN                NaN
# SWIFT                        NaN                     NaN                NaN
# SPARROW                      NaN                     NaN                NaN
# LARK                         NaN                     NaN                NaN
# CARDINAL                     NaN                     NaN                NaN
# JAY                          NaN                     NaN                NaN
# CROW                         NaN                     NaN                NaN
# LORIKEET                     NaN                     NaN                NaN
# MYNAH                        NaN                     NaN                NaN
# PARTRIDGE                    NaN                     NaN                NaN
# CASSOWARY                    NaN                     NaN                NaN
# ORIOLE                       NaN                     NaN                NaN
# WARBLER                      NaN                     NaN                NaN
# HARPY                        NaN                     NaN                NaN
# BEE-EATER                    NaN                     NaN                NaN
# LOON                         NaN                     NaN                NaN
# CUCKOO                       NaN                     NaN                NaN
# ROOSTER                      NaN                     NaN                NaN
# ARCHAEOPTERYX                NaN                     NaN                NaN
# TERN                         NaN                     NaN                NaN
# STILT                        NaN                     NaN                NaN
# AVOCET                       NaN                     NaN                NaN
# OSTRICH                      NaN                     NaN                NaN
# EMU                          NaN                     NaN                NaN
# DUCK                         NaN                     NaN                NaN
# HERON                        NaN                     NaN                NaN
# STORK                        NaN                     NaN                NaN
# SWAN                         NaN                     NaN                NaN
# PARROT                       NaN                     NaN                NaN
# CRANE                        NaN                     NaN                NaN
# IBIS                         NaN                     NaN                NaN
# EGRET                        NaN                     NaN                NaN
# PHEASANT                     NaN                     NaN                NaN
# MACAW                        NaN                     NaN                NaN
# FLAMINGO                     NaN                     NaN                NaN
# PEACOCK                      NaN                     NaN                NaN
# PENGUIN                      NaN                     NaN                NaN
# ALBATROSS                    NaN                     NaN                NaN
# PELICAN                      NaN                     NaN                NaN
# OWL                          NaN                     NaN                NaN
# FINCH                        NaN                     NaN                NaN
# ROBIN                        NaN                     NaN                NaN
# BLUEBIRD                     NaN                     NaN                NaN
# CANARY                       NaN                     NaN                NaN
# SEAGULL                      NaN                     NaN                NaN
# HUMMINGBIRD                  NaN                     NaN                NaN
# PHOENIX                      NaN                     NaN                NaN
# TOUCAN                       NaN                     NaN                NaN
# GOOSE                        NaN                     NaN                NaN
#
# Lease          Casing Footage 2 (ft)   Casing Depth (ft)   \
# OSPREY                           6307               13248
# FALCON                            NaN                 NaN
# HAWK                              NaN                 NaN
# EAGLE                             NaN                 NaN
# KITE                              NaN                 NaN
# SWIFT                             NaN                 NaN
# SPARROW                           NaN                 NaN
# LARK                              NaN                 NaN
# CARDINAL                          NaN                 NaN
# JAY                               NaN                 NaN
# CROW                              NaN                 NaN
# LORIKEET                          NaN                 NaN
# MYNAH                             NaN                 NaN
# PARTRIDGE                         NaN                 NaN
# CASSOWARY                         NaN                 NaN
# ORIOLE                            NaN                 NaN
# WARBLER                           NaN                 NaN
# HARPY                             NaN                 NaN
# BEE-EATER                         NaN                 NaN
# LOON                              NaN                 NaN
# CUCKOO                            NaN                 NaN
# ROOSTER                           NaN                 NaN
# ARCHAEOPTERYX                     NaN                 NaN
# TERN                              NaN                 NaN
# STILT                             NaN                 NaN
# AVOCET                            NaN                 NaN
# OSTRICH                           NaN                 NaN
# EMU                               NaN                 NaN
# DUCK                              NaN                 NaN
# HERON                             NaN                 NaN
# STORK                             NaN                 NaN
# SWAN                              NaN                 NaN
# PARROT                            NaN                 NaN
# CRANE                             NaN                 NaN
# IBIS                              NaN                 NaN
# EGRET                             NaN                 NaN
# PHEASANT                          NaN                 NaN
# MACAW                             NaN                 NaN
# FLAMINGO                          NaN                 NaN
# PEACOCK                           NaN                 NaN
# PENGUIN                           NaN                 NaN
# ALBATROSS                         NaN                 NaN
# PELICAN                           NaN                 NaN
# OWL                               NaN                 NaN
# FINCH                             NaN                 NaN
# ROBIN                             NaN                 NaN
# BLUEBIRD                          NaN                 NaN
# CANARY                            NaN                 NaN
# SEAGULL                           NaN                 NaN
# HUMMINGBIRD                       NaN                 NaN
# PHOENIX                           NaN                 NaN
# TOUCAN                            NaN                 NaN
# GOOSE                             NaN                 NaN
#
# Lease                                               Description
# OSPREY          Well began producing and was later recomplete...
# FALCON          Interior well on a 3-well pad that was shut-i...
# HAWK            Exterior well on a 3-well pad that was shut-i...
# EAGLE           Single unbounded well with modern completion ...
# KITE            Child well with modern completion design offs...
# SWIFT           Exterior well on a 2-well pad with modern com...
# SPARROW         Exterior well on a 2-well pad with modern com...
# LARK            Exterior well on a 3-well pad with modern com...
# CARDINAL        Exterior well on a 3-well pad with modern com...
# JAY             Interior well on a 3-well pad with modern com...
# CROW            Child well that was codeveloped with adjacent...
# LORIKEET                             SNG; Unbounded legacy well
# MYNAH           CCD; Modern completions infilled between lega...
# PARTRIDGE       CCD; Modern completions infilled between lega...
# CASSOWARY       PDB; CLS parent later offset by modern comple...
# ORIOLE          CCD; Modern 3 well development infilled betwe...
# WARBLER         CLD; Modern 3 well development infilled betwe...
# HARPY           CCD; Modern 3 well development infilled betwe...
# BEE-EATER       CCD; Modern completion comparison for twin pa...
# LOON              CLS; Wider CS & increase #/cl completion test
# CUCKOO                                        SNG; Bossier well
# ROOSTER                      CLS; Increase #/cl completion test
# ARCHAEOPTERYX   CCD; Modern completions infilled between lega...
# TERN            CCD; Modern completions infilled between lega...
# STILT           CCD; Modern completions infilled between lega...
# AVOCET          CCD; Modern completions infilled between lega...
# OSTRICH         CLUSTER UNBOUND; Clean data, data suggest lar...
# EMU                     CLUSTER BOUND; Modern Completion design
# DUCK            PARENT; Modern Completion design, high IP, cl...
# HERON           CLUSTER BOUND; co-developed, single bounded d...
# STORK                     CHILD BOUND; double bounded depletion
# SWAN            CHILD BOUND; co-developed, single bound deple...
# PARROT                       PARENT; co-developed, no depletion
# CRANE           CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# IBIS            CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# EGRET                       unbounded; Largest CUM in Marcellus
# PHEASANT        SINGLE; Modern Completion design, high Ark an...
# MACAW                        1500' innerwell unbounded exterior
# FLAMINGO                     1500' innerwell unbounded exterior
# PEACOCK                      1500' innerwell unbounded exterior
# PENGUIN                      1500' innerwell unbounded exterior
# ALBATROSS                                             Unbounded
# PELICAN                      1200' innerwell unbounded exterior
# OWL                          1200' innerwell unbounded exterior
# FINCH                                                     1700'
# ROBIN                                                     1700'
# BLUEBIRD                     1500' innerwell unbounded exterior
# CANARY                       1500' innerwell unbounded exterior
# SEAGULL                      1300' innerwell unbounded exterior
# HUMMINGBIRD                  1300' innerwell unbounded exterior
# PHOENIX                       900' innerwell unbounded exterior
# TOUCAN                        900' innerwell unbounded exterior
# GOOSE                                                 Unbounded
#
# [53 rows x 94 columns]

# %% [markdown]
# Удаляю символ %.

# %%
well_data.replace(to_replace=r'%$', value='', regex=True, inplace=True)

# %%
well_data.to_csv('well_data_modified.csv')

# %%
well_data = pd.read_csv('well_data_modified.csv', index_col=0); well_data
# Out:
#                Well Number State Formation/Reservoir  \
# OSPREY                   1    TX          EAGLE FORD
# FALCON                   2    TX          EAGLE FORD
# HAWK                     3    TX          EAGLE FORD
# EAGLE                    4    TX          EAGLE FORD
# KITE                     5    TX          EAGLE FORD
# SWIFT                    6    TX          EAGLE FORD
# SPARROW                  7    TX          EAGLE FORD
# LARK                     8    TX          EAGLE FORD
# CARDINAL                 9    TX          EAGLE FORD
# JAY                     10    TX          EAGLE FORD
# CROW                    11    TX          EAGLE FORD
# LORIKEET                62    LA   HAYNESVILLE SHALE
# MYNAH                   63    LA   HAYNESVILLE SHALE
# PARTRIDGE               64    LA   HAYNESVILLE SHALE
# CASSOWARY               65    LA   HAYNESVILLE SHALE
# ORIOLE                  66    LA   HAYNESVILLE SHALE
# WARBLER                 67    LA   HAYNESVILLE SHALE
# HARPY                   68    LA   HAYNESVILLE SHALE
# BEE-EATER               69    LA   HAYNESVILLE SHALE
# LOON                    70    LA   HAYNESVILLE SHALE
# CUCKOO                  71    LA      BOSSIER SHALE
# ROOSTER                 72    LA   HAYNESVILLE SHALE
# ARCHAEOPTERYX           73    LA   HAYNESVILLE SHALE
# TERN                    74    LA   HAYNESVILLE SHALE
# STILT                   75    LA   HAYNESVILLE SHALE
# AVOCET                  76    LA   HAYNESVILLE SHALE
# OSTRICH                 23    PA           MARCELLUS
# EMU                     24    PA           MARCELLUS
# DUCK                    25    PA           MARCELLUS
# HERON                   26    PA           MARCELLUS
# STORK                   27    PA           MARCELLUS
# SWAN                    28    PA           MARCELLUS
# PARROT                  29    PA           MARCELLUS
# CRANE                   30    PA           MARCELLUS
# IBIS                    31    PA           MARCELLUS
# EGRET                   32    PA           MARCELLUS
# PHEASANT                33    PA           MARCELLUS
# MACAW                   34    PA   MARCELLUS - UPPER
# FLAMINGO                35    PA   MARCELLUS - UPPER
# PEACOCK                 36    PA   MARCELLUS - UPPER
# PENGUIN                 37    PA   MARCELLUS - UPPER
# ALBATROSS               38    PA   MARCELLUS - UPPER
# PELICAN                 39    PA   MARCELLUS - UPPER
# OWL                     40    PA   MARCELLUS - UPPER
# FINCH                   41    PA   MARCELLUS - UPPER
# ROBIN                   42    PA   MARCELLUS - UPPER
# BLUEBIRD                43    PA   MARCELLUS - UPPER
# CANARY                  44    PA   MARCELLUS - UPPER
# SEAGULL                 45    PA   MARCELLUS - UPPER
# HUMMINGBIRD             46    PA   MARCELLUS - UPPER
# PHOENIX                 47    PA   MARCELLUS - UPPER
# TOUCAN                  48    PA   MARCELLUS - UPPER
# GOOSE                   49    PA   MARCELLUS - UPPER
#
#                 Initial Pressure Estimate (psi)   \
# OSPREY                                      5400
# FALCON                                      5700
# HAWK                                        5650
# EAGLE                                       5000
# KITE                                        5000
# SWIFT                                       5164
# SPARROW                                     5164
# LARK                                        5700
# CARDINAL                                    5900
# JAY                                         5700
# CROW                                        5500
# LORIKEET                                    9939
# MYNAH                                       9800
# PARTRIDGE                                   9900
# CASSOWARY                                  12223
# ORIOLE                                     11325
# WARBLER                                    11000
# HARPY                                      11325
# BEE-EATER                                  10000
# LOON                                       10000
# CUCKOO                                     10500
# ROOSTER                                    10500
# ARCHAEOPTERYX                              10300
# TERN                                       10450
# STILT                                      10800
# AVOCET                                     11000
# OSTRICH                                     3486
# EMU                                         5531
# DUCK                                        3900
# HERON                                       3500
# STORK                                       3000
# SWAN                                        4500
# PARROT                                      4750
# CRANE                                       5538
# IBIS                                        5508
# EGRET                                       5227
# PHEASANT                                    4450
# MACAW                                       4609
# FLAMINGO                                    4500
# PEACOCK                                     3150
# PENGUIN                                     3400
# ALBATROSS                                   5000
# PELICAN                                     2500
# OWL                                         2200
# FINCH                                       4300
# ROBIN                                       4100
# BLUEBIRD                                    4200
# CANARY                                      4300
# SEAGULL                                     4400
# HUMMINGBIRD                                 4000
# PHOENIX                                     4450
# TOUCAN                                      3900
# GOOSE                                       5200
#
#                 Reservoir Temperature (deg F)    Net Pay (ft)   \
# OSPREY                                     225              78
# FALCON                                     225              66
# HAWK                                       225              67
# EAGLE                                      235              74
# KITE                                       238              56
# SWIFT                                      225              63
# SPARROW                                    225              62
# LARK                                       228              68
# CARDINAL                                   228              67
# JAY                                        228              67
# CROW                                       221              63
# LORIKEET                                   285             268
# MYNAH                                      351             208
# PARTRIDGE                                  351             209
# CASSOWARY                                  331             161
# ORIOLE                                     343             166
# WARBLER                                    335             166
# HARPY                                      343             166
# BEE-EATER                                  379             165
# LOON                                       379             165
# CUCKOO                                     305             150
# ROOSTER                                    350             180
# ARCHAEOPTERYX                              343             183
# TERN                                       329             193
# STILT                                      346             150
# AVOCET                                     348             150
# OSTRICH                                    115             102
# EMU                                        143             132
# DUCK                                       137             134
# HERON                                      133             150
# STORK                                      133             150
# SWAN                                       134             150
# PARROT                                     135             148
# CRANE                                      146             134
# IBIS                                       146             134
# EGRET                                      134             143
# PHEASANT                                   130             142
# MACAW                                      135             164
# FLAMINGO                                   135             164
# PEACOCK                                    125             231
# PENGUIN                                    125             232
# ALBATROSS                                  126             170
# PELICAN                                    136             245
# OWL                                        136             246
# FINCH                                      133             177
# ROBIN                                      133             177
# BLUEBIRD                                   125             241
# CANARY                                     133             241
# SEAGULL                                    136             230
# HUMMINGBIRD                                136             230
# PHOENIX                                    137             232
# TOUCAN                                     137             232
# GOOSE                                      134             223
#
#                 Wellbore Diameter (ft)   Porosity   Water Saturation   \
# OSPREY                              0.7      6.30               26.00
# FALCON                              0.7      6.30               27.00
# HAWK                                0.7      6.30               27.10
# EAGLE                               0.7      6.30               27.00
# KITE                                0.7      5.00               32.10
# SWIFT                               0.7      5.20               33.10
# SPARROW                             0.7      5.20               33.20
# LARK                                0.7      5.20               36.30
# CARDINAL                            0.7      5.20               36.00
# JAY                                 0.7      5.20               36.10
# CROW                                0.7      5.20               32.10
# LORIKEET                            0.7      8.80               18.38
# MYNAH                               0.7      8.84               20.25
# PARTRIDGE                           0.7      8.84               20.25
# CASSOWARY                           0.7      9.10               19.07
# ORIOLE                              0.7      8.56               20.09
# WARBLER                             0.7      8.55               20.09
# HARPY                               0.7      8.56               20.09
# BEE-EATER                           0.7      9.10               20.00
# LOON                                0.7      9.10               20.00
# CUCKOO                              0.7     10.00               20.00
# ROOSTER                             0.7      8.00               20.00
# ARCHAEOPTERYX                       0.7      8.61               21.00
# TERN                                0.7      8.61               21.00
# STILT                               0.7      8.39               22.90
# AVOCET                              0.7      8.39               22.90
# OSTRICH                             0.7      7.00               32.97
# EMU                                 0.7      6.35               19.60
# DUCK                                0.7      6.94               31.59
# HERON                               0.7      7.44               22.94
# STORK                               0.7      7.49               21.03
# SWAN                                0.7      7.11               31.08
# PARROT                              0.7      7.08               30.93
# CRANE                               0.7      6.36               34.84
# IBIS                                0.7      6.37               34.89
# EGRET                               0.7      8.11               43.59
# PHEASANT                            0.7      7.86               39.28
# MACAW                               0.7      6.52               27.00
# FLAMINGO                            0.7      6.52               27.00
# PEACOCK                             0.7      6.75               27.00
# PENGUIN                             0.7      6.72               26.00
# ALBATROSS                           0.7      6.39               38.00
# PELICAN                             0.7      5.31               40.00
# OWL                                 0.7      5.29               39.00
# FINCH                               0.7      7.23               41.29
# ROBIN                               0.7      7.23               41.28
# BLUEBIRD                            0.7      6.03               35.00
# CANARY                              0.7      6.03               35.00
# SEAGULL                             0.7      5.99               43.00
# HUMMINGBIRD                         0.7      5.99               43.00
# PHOENIX                             0.7      5.87               47.00
# TOUCAN                              0.7      5.87               47.00
# GOOSE                               0.7      6.17               40.22
#
#                 Oil Saturation   ...  Pressure Loss Correlation.4  \
# OSPREY                    74.00  ...                Beggs & Brill
# FALCON                    73.00  ...                          NaN
# HAWK                      72.90  ...                          NaN
# EAGLE                     73.00  ...                          NaN
# KITE                      67.90  ...                          NaN
# SWIFT                     66.90  ...                          NaN
# SPARROW                   66.80  ...                          NaN
# LARK                      63.70  ...                          NaN
# CARDINAL                  64.00  ...                          NaN
# JAY                       60.20  ...                          NaN
# CROW                      67.90  ...                          NaN
# LORIKEET                   0.00  ...                          NaN
# MYNAH                      0.00  ...                          NaN
# PARTRIDGE                  0.00  ...                          NaN
# CASSOWARY                  0.00  ...                          NaN
# ORIOLE                     0.00  ...                          NaN
# WARBLER                    0.00  ...                          NaN
# HARPY                      0.00  ...                          NaN
# BEE-EATER                  0.00  ...                          NaN
# LOON                       0.00  ...                          NaN
# CUCKOO                     0.00  ...                          NaN
# ROOSTER                    0.00  ...                          NaN
# ARCHAEOPTERYX              0.00  ...                          NaN
# TERN                       0.00  ...                          NaN
# STILT                      0.00  ...                          NaN
# AVOCET                     0.00  ...                          NaN
# OSTRICH                    0.13  ...                          NaN
# EMU                        0.00  ...                          NaN
# DUCK                       0.00  ...                          NaN
# HERON                      0.00  ...                          NaN
# STORK                      0.00  ...                          NaN
# SWAN                       0.00  ...                          NaN
# PARROT                     0.00  ...                          NaN
# CRANE                      0.00  ...                          NaN
# IBIS                       0.00  ...                          NaN
# EGRET                      0.00  ...                          NaN
# PHEASANT                   0.00  ...                          NaN
# MACAW                      0.00  ...                          NaN
# FLAMINGO                   0.00  ...                          NaN
# PEACOCK                    0.00  ...                          NaN
# PENGUIN                    0.00  ...                          NaN
# ALBATROSS                  0.00  ...                          NaN
# PELICAN                    0.00  ...                          NaN
# OWL                        0.00  ...                          NaN
# FINCH                      0.00  ...                          NaN
# ROBIN                      0.00  ...                          NaN
# BLUEBIRD                   0.00  ...                          NaN
# CANARY                     0.00  ...                          NaN
# SEAGULL                    0.00  ...                          NaN
# HUMMINGBIRD                0.00  ...                          NaN
# PHOENIX                    0.00  ...                          NaN
# TOUCAN                     0.00  ...                          NaN
# GOOSE                      0.00  ...                          NaN
#
#                 Tubing ID (in) .4   Tubing OD (in) .4   Tubing Depth (ft) .4  \
# OSPREY                      2.441               2.875                 6764.0
# FALCON                        NaN                 NaN                    NaN
# HAWK                          NaN                 NaN                    NaN
# EAGLE                         NaN                 NaN                    NaN
# KITE                          NaN                 NaN                    NaN
# SWIFT                         NaN                 NaN                    NaN
# SPARROW                       NaN                 NaN                    NaN
# LARK                          NaN                 NaN                    NaN
# CARDINAL                      NaN                 NaN                    NaN
# JAY                           NaN                 NaN                    NaN
# CROW                          NaN                 NaN                    NaN
# LORIKEET                      NaN                 NaN                    NaN
# MYNAH                         NaN                 NaN                    NaN
# PARTRIDGE                     NaN                 NaN                    NaN
# CASSOWARY                     NaN                 NaN                    NaN
# ORIOLE                        NaN                 NaN                    NaN
# WARBLER                       NaN                 NaN                    NaN
# HARPY                         NaN                 NaN                    NaN
# BEE-EATER                     NaN                 NaN                    NaN
# LOON                          NaN                 NaN                    NaN
# CUCKOO                        NaN                 NaN                    NaN
# ROOSTER                       NaN                 NaN                    NaN
# ARCHAEOPTERYX                 NaN                 NaN                    NaN
# TERN                          NaN                 NaN                    NaN
# STILT                         NaN                 NaN                    NaN
# AVOCET                        NaN                 NaN                    NaN
# OSTRICH                       NaN                 NaN                    NaN
# EMU                           NaN                 NaN                    NaN
# DUCK                          NaN                 NaN                    NaN
# HERON                         NaN                 NaN                    NaN
# STORK                         NaN                 NaN                    NaN
# SWAN                          NaN                 NaN                    NaN
# PARROT                        NaN                 NaN                    NaN
# CRANE                         NaN                 NaN                    NaN
# IBIS                          NaN                 NaN                    NaN
# EGRET                         NaN                 NaN                    NaN
# PHEASANT                      NaN                 NaN                    NaN
# MACAW                         NaN                 NaN                    NaN
# FLAMINGO                      NaN                 NaN                    NaN
# PEACOCK                       NaN                 NaN                    NaN
# PENGUIN                       NaN                 NaN                    NaN
# ALBATROSS                     NaN                 NaN                    NaN
# PELICAN                       NaN                 NaN                    NaN
# OWL                           NaN                 NaN                    NaN
# FINCH                         NaN                 NaN                    NaN
# ROBIN                         NaN                 NaN                    NaN
# BLUEBIRD                      NaN                 NaN                    NaN
# CANARY                        NaN                 NaN                    NaN
# SEAGULL                       NaN                 NaN                    NaN
# HUMMINGBIRD                   NaN                 NaN                    NaN
# PHOENIX                       NaN                 NaN                    NaN
# TOUCAN                        NaN                 NaN                    NaN
# GOOSE                         NaN                 NaN                    NaN
#
#                 Casing ID 1 (in) .4   Casing Footage 1 (ft) .4  \
# OSPREY                         4.67                     6941.0
# FALCON                          NaN                        NaN
# HAWK                            NaN                        NaN
# EAGLE                           NaN                        NaN
# KITE                            NaN                        NaN
# SWIFT                           NaN                        NaN
# SPARROW                         NaN                        NaN
# LARK                            NaN                        NaN
# CARDINAL                        NaN                        NaN
# JAY                             NaN                        NaN
# CROW                            NaN                        NaN
# LORIKEET                        NaN                        NaN
# MYNAH                           NaN                        NaN
# PARTRIDGE                       NaN                        NaN
# CASSOWARY                       NaN                        NaN
# ORIOLE                          NaN                        NaN
# WARBLER                         NaN                        NaN
# HARPY                           NaN                        NaN
# BEE-EATER                       NaN                        NaN
# LOON                            NaN                        NaN
# CUCKOO                          NaN                        NaN
# ROOSTER                         NaN                        NaN
# ARCHAEOPTERYX                   NaN                        NaN
# TERN                            NaN                        NaN
# STILT                           NaN                        NaN
# AVOCET                          NaN                        NaN
# OSTRICH                         NaN                        NaN
# EMU                             NaN                        NaN
# DUCK                            NaN                        NaN
# HERON                           NaN                        NaN
# STORK                           NaN                        NaN
# SWAN                            NaN                        NaN
# PARROT                          NaN                        NaN
# CRANE                           NaN                        NaN
# IBIS                            NaN                        NaN
# EGRET                           NaN                        NaN
# PHEASANT                        NaN                        NaN
# MACAW                           NaN                        NaN
# FLAMINGO                        NaN                        NaN
# PEACOCK                         NaN                        NaN
# PENGUIN                         NaN                        NaN
# ALBATROSS                       NaN                        NaN
# PELICAN                         NaN                        NaN
# OWL                             NaN                        NaN
# FINCH                           NaN                        NaN
# ROBIN                           NaN                        NaN
# BLUEBIRD                        NaN                        NaN
# CANARY                          NaN                        NaN
# SEAGULL                         NaN                        NaN
# HUMMINGBIRD                     NaN                        NaN
# PHOENIX                         NaN                        NaN
# TOUCAN                          NaN                        NaN
# GOOSE                           NaN                        NaN
#
#                 Casing ID 2 (in) .4   Casing Footage 2 (ft) .4  \
# OSPREY                        2.992                     6307.0
# FALCON                          NaN                        NaN
# HAWK                            NaN                        NaN
# EAGLE                           NaN                        NaN
# KITE                            NaN                        NaN
# SWIFT                           NaN                        NaN
# SPARROW                         NaN                        NaN
# LARK                            NaN                        NaN
# CARDINAL                        NaN                        NaN
# JAY                             NaN                        NaN
# CROW                            NaN                        NaN
# LORIKEET                        NaN                        NaN
# MYNAH                           NaN                        NaN
# PARTRIDGE                       NaN                        NaN
# CASSOWARY                       NaN                        NaN
# ORIOLE                          NaN                        NaN
# WARBLER                         NaN                        NaN
# HARPY                           NaN                        NaN
# BEE-EATER                       NaN                        NaN
# LOON                            NaN                        NaN
# CUCKOO                          NaN                        NaN
# ROOSTER                         NaN                        NaN
# ARCHAEOPTERYX                   NaN                        NaN
# TERN                            NaN                        NaN
# STILT                           NaN                        NaN
# AVOCET                          NaN                        NaN
# OSTRICH                         NaN                        NaN
# EMU                             NaN                        NaN
# DUCK                            NaN                        NaN
# HERON                           NaN                        NaN
# STORK                           NaN                        NaN
# SWAN                            NaN                        NaN
# PARROT                          NaN                        NaN
# CRANE                           NaN                        NaN
# IBIS                            NaN                        NaN
# EGRET                           NaN                        NaN
# PHEASANT                        NaN                        NaN
# MACAW                           NaN                        NaN
# FLAMINGO                        NaN                        NaN
# PEACOCK                         NaN                        NaN
# PENGUIN                         NaN                        NaN
# ALBATROSS                       NaN                        NaN
# PELICAN                         NaN                        NaN
# OWL                             NaN                        NaN
# FINCH                           NaN                        NaN
# ROBIN                           NaN                        NaN
# BLUEBIRD                        NaN                        NaN
# CANARY                          NaN                        NaN
# SEAGULL                         NaN                        NaN
# HUMMINGBIRD                     NaN                        NaN
# PHOENIX                         NaN                        NaN
# TOUCAN                          NaN                        NaN
# GOOSE                           NaN                        NaN
#
#                 Casing Depth (ft) .4  \
# OSPREY                       13248.0
# FALCON                           NaN
# HAWK                             NaN
# EAGLE                            NaN
# KITE                             NaN
# SWIFT                            NaN
# SPARROW                          NaN
# LARK                             NaN
# CARDINAL                         NaN
# JAY                              NaN
# CROW                             NaN
# LORIKEET                         NaN
# MYNAH                            NaN
# PARTRIDGE                        NaN
# CASSOWARY                        NaN
# ORIOLE                           NaN
# WARBLER                          NaN
# HARPY                            NaN
# BEE-EATER                        NaN
# LOON                             NaN
# CUCKOO                           NaN
# ROOSTER                          NaN
# ARCHAEOPTERYX                    NaN
# TERN                             NaN
# STILT                            NaN
# AVOCET                           NaN
# OSTRICH                          NaN
# EMU                              NaN
# DUCK                             NaN
# HERON                            NaN
# STORK                            NaN
# SWAN                             NaN
# PARROT                           NaN
# CRANE                            NaN
# IBIS                             NaN
# EGRET                            NaN
# PHEASANT                         NaN
# MACAW                            NaN
# FLAMINGO                         NaN
# PEACOCK                          NaN
# PENGUIN                          NaN
# ALBATROSS                        NaN
# PELICAN                          NaN
# OWL                              NaN
# FINCH                            NaN
# ROBIN                            NaN
# BLUEBIRD                         NaN
# CANARY                           NaN
# SEAGULL                          NaN
# HUMMINGBIRD                      NaN
# PHOENIX                          NaN
# TOUCAN                           NaN
# GOOSE                            NaN
#
#                                                     Description
# OSPREY          Well began producing and was later recomplete...
# FALCON          Interior well on a 3-well pad that was shut-i...
# HAWK            Exterior well on a 3-well pad that was shut-i...
# EAGLE           Single unbounded well with modern completion ...
# KITE            Child well with modern completion design offs...
# SWIFT           Exterior well on a 2-well pad with modern com...
# SPARROW         Exterior well on a 2-well pad with modern com...
# LARK            Exterior well on a 3-well pad with modern com...
# CARDINAL        Exterior well on a 3-well pad with modern com...
# JAY             Interior well on a 3-well pad with modern com...
# CROW            Child well that was codeveloped with adjacent...
# LORIKEET                             SNG; Unbounded legacy well
# MYNAH           CCD; Modern completions infilled between lega...
# PARTRIDGE       CCD; Modern completions infilled between lega...
# CASSOWARY       PDB; CLS parent later offset by modern comple...
# ORIOLE          CCD; Modern 3 well development infilled betwe...
# WARBLER         CLD; Modern 3 well development infilled betwe...
# HARPY           CCD; Modern 3 well development infilled betwe...
# BEE-EATER       CCD; Modern completion comparison for twin pa...
# LOON              CLS; Wider CS & increase #/cl completion test
# CUCKOO                                        SNG; Bossier well
# ROOSTER                      CLS; Increase #/cl completion test
# ARCHAEOPTERYX   CCD; Modern completions infilled between lega...
# TERN            CCD; Modern completions infilled between lega...
# STILT           CCD; Modern completions infilled between lega...
# AVOCET          CCD; Modern completions infilled between lega...
# OSTRICH         CLUSTER UNBOUND; Clean data, data suggest lar...
# EMU                     CLUSTER BOUND; Modern Completion design
# DUCK            PARENT; Modern Completion design, high IP, cl...
# HERON           CLUSTER BOUND; co-developed, single bounded d...
# STORK                     CHILD BOUND; double bounded depletion
# SWAN            CHILD BOUND; co-developed, single bound deple...
# PARROT                       PARENT; co-developed, no depletion
# CRANE           CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# IBIS            CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# EGRET                       unbounded; Largest CUM in Marcellus
# PHEASANT        SINGLE; Modern Completion design, high Ark an...
# MACAW                        1500' innerwell unbounded exterior
# FLAMINGO                     1500' innerwell unbounded exterior
# PEACOCK                      1500' innerwell unbounded exterior
# PENGUIN                      1500' innerwell unbounded exterior
# ALBATROSS                                             Unbounded
# PELICAN                      1200' innerwell unbounded exterior
# OWL                          1200' innerwell unbounded exterior
# FINCH                                                     1700'
# ROBIN                                                     1700'
# BLUEBIRD                     1500' innerwell unbounded exterior
# CANARY                       1500' innerwell unbounded exterior
# SEAGULL                      1300' innerwell unbounded exterior
# HUMMINGBIRD                  1300' innerwell unbounded exterior
# PHOENIX                       900' innerwell unbounded exterior
# TOUCAN                        900' innerwell unbounded exterior
# GOOSE                                                 Unbounded
#
# [53 rows x 94 columns]

# %%
well_data.dtypes
# Out:
# Well Number                            int64
# State                                 object
# Formation/Reservoir                   object
#  Initial Pressure Estimate (psi)       int64
#  Reservoir Temperature (deg F)         int64
#                                       ...
#  Casing Footage 1 (ft) .4            float64
#  Casing ID 2 (in) .4                 float64
#  Casing Footage 2 (ft) .4            float64
#  Casing Depth (ft) .4                float64
#  Description                          object
# Length: 94, dtype: object

# %% [markdown]
# Теперь результаты измерений имеют числовой формат

# %% [markdown]
# ## Категориальные переменные

# %%
well_data.select_dtypes(include='object')
# Out:
#               State Formation/Reservoir   Spacing   \
# OSPREY           TX          EAGLE FORD       1400
# FALCON           TX          EAGLE FORD       1000
# HAWK             TX          EAGLE FORD       1000
# EAGLE            TX          EAGLE FORD  Unbounded
# KITE             TX          EAGLE FORD       1400
# SWIFT            TX          EAGLE FORD       1500
# SPARROW          TX          EAGLE FORD       1500
# LARK             TX          EAGLE FORD        800
# CARDINAL         TX          EAGLE FORD        700
# JAY              TX          EAGLE FORD        700
# CROW             TX          EAGLE FORD       1300
# LORIKEET         LA   HAYNESVILLE SHALE        NaN
# MYNAH            LA   HAYNESVILLE SHALE       1000
# PARTRIDGE        LA   HAYNESVILLE SHALE       1000
# CASSOWARY        LA   HAYNESVILLE SHALE       1300
# ORIOLE           LA   HAYNESVILLE SHALE        850
# WARBLER          LA   HAYNESVILLE SHALE        850
# HARPY            LA   HAYNESVILLE SHALE        850
# BEE-EATER        LA   HAYNESVILLE SHALE       1050
# LOON             LA   HAYNESVILLE SHALE       1050
# CUCKOO           LA      BOSSIER SHALE         NaN
# ROOSTER          LA   HAYNESVILLE SHALE       1250
# ARCHAEOPTERYX    LA   HAYNESVILLE SHALE       1050
# TERN             LA   HAYNESVILLE SHALE       1050
# STILT            LA   HAYNESVILLE SHALE        850
# AVOCET           LA   HAYNESVILLE SHALE        850
# OSTRICH          PA           MARCELLUS        NaN
# EMU              PA           MARCELLUS       1850
# DUCK             PA           MARCELLUS       1650
# HERON            PA           MARCELLUS       1500
# STORK            PA           MARCELLUS       1400
# SWAN             PA           MARCELLUS       1300
# PARROT           PA           MARCELLUS       1250
# CRANE            PA           MARCELLUS        830
# IBIS             PA           MARCELLUS        830
# EGRET            PA           MARCELLUS        NaN
# PHEASANT         PA           MARCELLUS       1800
# MACAW            PA   MARCELLUS - UPPER       1500
# FLAMINGO         PA   MARCELLUS - UPPER       1500
# PEACOCK          PA   MARCELLUS - UPPER       1500
# PENGUIN          PA   MARCELLUS - UPPER       1500
# ALBATROSS        PA   MARCELLUS - UPPER        NaN
# PELICAN          PA   MARCELLUS - UPPER       1200
# OWL              PA   MARCELLUS - UPPER       1200
# FINCH            PA   MARCELLUS - UPPER       1700
# ROBIN            PA   MARCELLUS - UPPER       1700
# BLUEBIRD         PA   MARCELLUS - UPPER       1500
# CANARY           PA   MARCELLUS - UPPER       1500
# SEAGULL          PA   MARCELLUS - UPPER       1300
# HUMMINGBIRD      PA   MARCELLUS - UPPER       1300
# PHOENIX          PA   MARCELLUS - UPPER        900
# TOUCAN           PA   MARCELLUS - UPPER        900
# GOOSE            PA   MARCELLUS - UPPER        NaN
#
#                                        # of Total Proppant (Lbs)  \
# OSPREY                                                  13514540
# FALCON                                                  35970960
# HAWK                                                    38064782
# EAGLE                                                   25267400
# KITE                                                    18554774
# SWIFT                                                   27785630
# SPARROW                                                 27550700
# LARK                                                    27024578
# CARDINAL                                                26576840
# JAY                                                     25986000
# CROW                                                    39020000
# LORIKEET                                               3,591,544
# MYNAH                                                 23,245,567
# PARTRIDGE                                             22,963,009
# CASSOWARY                                              6,134,650
# ORIOLE                                                27,197,082
# WARBLER                                               25,082,774
# HARPY                                                 26,976,378
# BEE-EATER                                             26,397,928
# LOON                                                  41,398,865
# CUCKOO                                                42,946,954
# ROOSTER                                               26,632,739
# ARCHAEOPTERYX                                         20,836,790
# TERN                                                  20,748,830
# STILT                                                 20,374,069
# AVOCET                                                20,174,551
# OSTRICH                                               7,194,425
# EMU                                                  18,404,917
# DUCK                                                 31,201,810
# HERON                                                12,051,645
# STORK                                                 8,680,895
# SWAN                                                 16,477,745
# PARROT                                               15,197,373
# CRANE                                                        ...
# IBIS                                                         ...
# EGRET                                                        ...
# PHEASANT                                                     ...
# MACAW                                                25,754,836
# FLAMINGO                                             24,374,215
# PEACOCK                                              38,875,334
# PENGUIN                                              26,695,450
# ALBATROSS                                             6,756,861
# PELICAN                                              13,662,881
# OWL                                                  14,163,366
# FINCH                                                       2...
# ROBIN                                                       1...
# BLUEBIRD                                                     ...
# CANARY                                                       ...
# SEAGULL                                              31,532,947
# HUMMINGBIRD                                          21,395,323
# PHOENIX                                              14,860,164
# TOUCAN                                               11,178,400
# GOOSE                                                 5,079,200
#
#               Total Fluid (Bbls)    Configuration  Production Path  \
# OSPREY                    275579   Initial Config           Casing
# FALCON                    559202   Initial Config           Tubing
# HAWK                      596128   Initial Config           Tubing
# EAGLE                     577003   Initial Config           Tubing
# KITE                      360202   Initial Config           Tubing
# SWIFT                     591971   Initial Config           Tubing
# SPARROW                   533414   Initial Config           Tubing
# LARK                      535169   Initial Config           Tubing
# CARDINAL                  542527   Initial Config           Tubing
# JAY                       519038   Initial Config           Tubing
# CROW                      575663   Initial Config           Tubing
# LORIKEET                  77,278   Initial Config           Casing
# MYNAH                    400,805   Initial Config           Casing
# PARTRIDGE                391,277   Initial Config           Casing
# CASSOWARY                144,387   Initial Config           Tubing
# ORIOLE                   471,447   Initial Config           Casing
# WARBLER                  454,354   Initial Config           Casing
# HARPY                    483,046   Initial Config           Casing
# BEE-EATER                450,784   Initial Config           Casing
# LOON                     648,033   Initial Config           Casing
# CUCKOO                   697,775   Initial Config           Casing
# ROOSTER                  530,797   Initial Config           Tubing
# ARCHAEOPTERYX            395,488   Initial Config           Casing
# TERN                     378,185   Initial Config           Casing
# STILT                    362,937   Initial Config           Casing
# AVOCET                   340,291   Initial Config           Casing
# OSTRICH                      NaN   Initial Config           Tubing
# EMU                          NaN   Initial Config           Casing
# DUCK                         NaN   Initial Config           Casing
# HERON                        NaN   Initial Config           Casing
# STORK                        NaN   Initial Config           Casing
# SWAN                         NaN   Initial Config           Casing
# PARROT                       NaN   Initial Config           Casing
# CRANE                        NaN   Initial Config           Tubing
# IBIS                         NaN   Initial Config           Tubing
# EGRET                        NaN   Initial Config           Tubing
# PHEASANT                     NaN   Initial Config           Casing
# MACAW                        NaN   Initial Config           Casing
# FLAMINGO                     NaN   Initial Config           Casing
# PEACOCK                      NaN   Initial Config           Casing
# PENGUIN                      NaN   Initial Config           Casing
# ALBATROSS                    NaN   Initial Config           Tubing
# PELICAN                      NaN   Initial Config           Casing
# OWL                          NaN   Initial Config           Casing
# FINCH                        NaN   Initial Config           Tubing
# ROBIN                        NaN   Initial Config           Tubing
# BLUEBIRD                     NaN   Initial Config           Casing
# CANARY                       NaN   Initial Config           Casing
# SEAGULL                      NaN   Initial Config           Casing
# HUMMINGBIRD                  NaN   Initial Config           Casing
# PHOENIX                      NaN   Initial Config           Casing
# TOUCAN                       NaN   Initial Config           Casing
# GOOSE                        NaN   Initial Config           Tubing
#
#               Pressure Loss Correlation Production Path.1  \
# OSPREY                    Beggs & Brill           Pumping
# FALCON                    Beggs & Brill          Gas Lift
# HAWK                      Beggs & Brill          Gas Lift
# EAGLE                     Beggs & Brill          Gas Lift
# KITE                      Beggs & Brill          Gas Lift
# SWIFT                     Beggs & Brill          Gas Lift
# SPARROW                   Beggs & Brill          Gas Lift
# LARK                      Beggs & Brill          Gas Lift
# CARDINAL                  Beggs & Brill          Gas Lift
# JAY                       Beggs & Brill          Gas Lift
# CROW                      Beggs & Brill          Gas Lift
# LORIKEET                           Gray            Tubing
# MYNAH                              Gray               NaN
# PARTRIDGE                          Gray               NaN
# CASSOWARY                          Gray               NaN
# ORIOLE                             Gray            Tubing
# WARBLER                            Gray            Tubing
# HARPY                              Gray            Tubing
# BEE-EATER                          Gray               NaN
# LOON                               Gray               NaN
# CUCKOO                             Gray            Tubing
# ROOSTER                            Gray               NaN
# ARCHAEOPTERYX                      Gray               NaN
# TERN                               Gray               NaN
# STILT                              Gray               NaN
# AVOCET                             Gray               NaN
# OSTRICH                            Gray               NaN
# EMU                                Gray            Tubing
# DUCK                               Gray               NaN
# HERON                              Gray               NaN
# STORK                              Gray               NaN
# SWAN                               Gray               NaN
# PARROT                             Gray               NaN
# CRANE                              Gray               NaN
# IBIS                               Gray               NaN
# EGRET                              Gray               NaN
# PHEASANT                           Gray               NaN
# MACAW                              Gray               NaN
# FLAMINGO                           Gray               NaN
# PEACOCK                            Gray               NaN
# PENGUIN                            Gray               NaN
# ALBATROSS                          Gray               NaN
# PELICAN                            Gray            Tubing
# OWL                                Gray            Tubing
# FINCH                              Gray               NaN
# ROBIN                              Gray               NaN
# BLUEBIRD                           Gray            Tubing
# CANARY                             Gray            Tubing
# SEAGULL                            Gray               NaN
# HUMMINGBIRD                        Gray               NaN
# PHOENIX                            Gray            Tubing
# TOUCAN                             Gray            Tubing
# GOOSE                              Gray               NaN
#
#               Pressure Loss Correlation.1 Production Path.2  \
# OSPREY                      Beggs & Brill            Tubing
# FALCON                      Beggs & Brill            Tubing
# HAWK                        Beggs & Brill            Tubing
# EAGLE                       Beggs & Brill               NaN
# KITE                        Beggs & Brill               NaN
# SWIFT                       Beggs & Brill           Pumping
# SPARROW                     Beggs & Brill           Pumping
# LARK                        Beggs & Brill           Pumping
# CARDINAL                    Beggs & Brill           Pumping
# JAY                         Beggs & Brill           Pumping
# CROW                        Beggs & Brill            Tubing
# LORIKEET                             Gray               NaN
# MYNAH                                 NaN               NaN
# PARTRIDGE                             NaN               NaN
# CASSOWARY                             NaN               NaN
# ORIOLE                               Gray               NaN
# WARBLER                              Gray               NaN
# HARPY                                Gray               NaN
# BEE-EATER                             NaN               NaN
# LOON                                  NaN               NaN
# CUCKOO                               Gray               NaN
# ROOSTER                               NaN               NaN
# ARCHAEOPTERYX                         NaN               NaN
# TERN                                  NaN               NaN
# STILT                                 NaN               NaN
# AVOCET                                NaN               NaN
# OSTRICH                               NaN               NaN
# EMU                                  Gray               NaN
# DUCK                                  NaN               NaN
# HERON                                 NaN               NaN
# STORK                                 NaN               NaN
# SWAN                                  NaN               NaN
# PARROT                                NaN               NaN
# CRANE                                 NaN               NaN
# IBIS                                  NaN               NaN
# EGRET                                 NaN               NaN
# PHEASANT                              NaN               NaN
# MACAW                                 NaN               NaN
# FLAMINGO                              NaN               NaN
# PEACOCK                               NaN               NaN
# PENGUIN                               NaN               NaN
# ALBATROSS                             NaN               NaN
# PELICAN                              Gray               NaN
# OWL                                  Gray               NaN
# FINCH                                 NaN               NaN
# ROBIN                                 NaN               NaN
# BLUEBIRD                             Gray               NaN
# CANARY                               Gray               NaN
# SEAGULL                               NaN               NaN
# HUMMINGBIRD                           NaN               NaN
# PHOENIX                              Gray               NaN
# TOUCAN                               Gray               NaN
# GOOSE                                 NaN               NaN
#
#               Pressure Loss Correlation.2 Production Path.3  \
# OSPREY                      Beggs & Brill          Gas Lift
# FALCON                      Beggs & Brill          Gas Lift
# HAWK                        Beggs & Brill          Gas Lift
# EAGLE                                 NaN               NaN
# KITE                                  NaN               NaN
# SWIFT                       Beggs & Brill               NaN
# SPARROW                     Beggs & Brill               NaN
# LARK                        Beggs & Brill               NaN
# CARDINAL                    Beggs & Brill               NaN
# JAY                         Beggs & Brill               NaN
# CROW                        Beggs & Brill          Gas Lift
# LORIKEET                              NaN               NaN
# MYNAH                                 NaN               NaN
# PARTRIDGE                             NaN               NaN
# CASSOWARY                             NaN               NaN
# ORIOLE                                NaN               NaN
# WARBLER                               NaN               NaN
# HARPY                                 NaN               NaN
# BEE-EATER                             NaN               NaN
# LOON                                  NaN               NaN
# CUCKOO                                NaN               NaN
# ROOSTER                               NaN               NaN
# ARCHAEOPTERYX                         NaN               NaN
# TERN                                  NaN               NaN
# STILT                                 NaN               NaN
# AVOCET                                NaN               NaN
# OSTRICH                               NaN               NaN
# EMU                                   NaN               NaN
# DUCK                                  NaN               NaN
# HERON                                 NaN               NaN
# STORK                                 NaN               NaN
# SWAN                                  NaN               NaN
# PARROT                                NaN               NaN
# CRANE                                 NaN               NaN
# IBIS                                  NaN               NaN
# EGRET                                 NaN               NaN
# PHEASANT                              NaN               NaN
# MACAW                                 NaN               NaN
# FLAMINGO                              NaN               NaN
# PEACOCK                               NaN               NaN
# PENGUIN                               NaN               NaN
# ALBATROSS                             NaN               NaN
# PELICAN                               NaN               NaN
# OWL                                   NaN               NaN
# FINCH                                 NaN               NaN
# ROBIN                                 NaN               NaN
# BLUEBIRD                              NaN               NaN
# CANARY                                NaN               NaN
# SEAGULL                               NaN               NaN
# HUMMINGBIRD                           NaN               NaN
# PHOENIX                               NaN               NaN
# TOUCAN                                NaN               NaN
# GOOSE                                 NaN               NaN
#
#               Pressure Loss Correlation.3 Production Path.4  \
# OSPREY                      Beggs & Brill           Pumping
# FALCON                      Beggs & Brill               NaN
# HAWK                        Beggs & Brill               NaN
# EAGLE                                 NaN               NaN
# KITE                                  NaN               NaN
# SWIFT                                 NaN               NaN
# SPARROW                               NaN               NaN
# LARK                                  NaN               NaN
# CARDINAL                              NaN               NaN
# JAY                                   NaN               NaN
# CROW                        Beggs & Brill               NaN
# LORIKEET                              NaN               NaN
# MYNAH                                 NaN               NaN
# PARTRIDGE                             NaN               NaN
# CASSOWARY                             NaN               NaN
# ORIOLE                                NaN               NaN
# WARBLER                               NaN               NaN
# HARPY                                 NaN               NaN
# BEE-EATER                             NaN               NaN
# LOON                                  NaN               NaN
# CUCKOO                                NaN               NaN
# ROOSTER                               NaN               NaN
# ARCHAEOPTERYX                         NaN               NaN
# TERN                                  NaN               NaN
# STILT                                 NaN               NaN
# AVOCET                                NaN               NaN
# OSTRICH                               NaN               NaN
# EMU                                   NaN               NaN
# DUCK                                  NaN               NaN
# HERON                                 NaN               NaN
# STORK                                 NaN               NaN
# SWAN                                  NaN               NaN
# PARROT                                NaN               NaN
# CRANE                                 NaN               NaN
# IBIS                                  NaN               NaN
# EGRET                                 NaN               NaN
# PHEASANT                              NaN               NaN
# MACAW                                 NaN               NaN
# FLAMINGO                              NaN               NaN
# PEACOCK                               NaN               NaN
# PENGUIN                               NaN               NaN
# ALBATROSS                             NaN               NaN
# PELICAN                               NaN               NaN
# OWL                                   NaN               NaN
# FINCH                                 NaN               NaN
# ROBIN                                 NaN               NaN
# BLUEBIRD                              NaN               NaN
# CANARY                                NaN               NaN
# SEAGULL                               NaN               NaN
# HUMMINGBIRD                           NaN               NaN
# PHOENIX                               NaN               NaN
# TOUCAN                                NaN               NaN
# GOOSE                                 NaN               NaN
#
#               Pressure Loss Correlation.4  \
# OSPREY                      Beggs & Brill
# FALCON                                NaN
# HAWK                                  NaN
# EAGLE                                 NaN
# KITE                                  NaN
# SWIFT                                 NaN
# SPARROW                               NaN
# LARK                                  NaN
# CARDINAL                              NaN
# JAY                                   NaN
# CROW                                  NaN
# LORIKEET                              NaN
# MYNAH                                 NaN
# PARTRIDGE                             NaN
# CASSOWARY                             NaN
# ORIOLE                                NaN
# WARBLER                               NaN
# HARPY                                 NaN
# BEE-EATER                             NaN
# LOON                                  NaN
# CUCKOO                                NaN
# ROOSTER                               NaN
# ARCHAEOPTERYX                         NaN
# TERN                                  NaN
# STILT                                 NaN
# AVOCET                                NaN
# OSTRICH                               NaN
# EMU                                   NaN
# DUCK                                  NaN
# HERON                                 NaN
# STORK                                 NaN
# SWAN                                  NaN
# PARROT                                NaN
# CRANE                                 NaN
# IBIS                                  NaN
# EGRET                                 NaN
# PHEASANT                              NaN
# MACAW                                 NaN
# FLAMINGO                              NaN
# PEACOCK                               NaN
# PENGUIN                               NaN
# ALBATROSS                             NaN
# PELICAN                               NaN
# OWL                                   NaN
# FINCH                                 NaN
# ROBIN                                 NaN
# BLUEBIRD                              NaN
# CANARY                                NaN
# SEAGULL                               NaN
# HUMMINGBIRD                           NaN
# PHOENIX                               NaN
# TOUCAN                                NaN
# GOOSE                                 NaN
#
#                                                     Description
# OSPREY          Well began producing and was later recomplete...
# FALCON          Interior well on a 3-well pad that was shut-i...
# HAWK            Exterior well on a 3-well pad that was shut-i...
# EAGLE           Single unbounded well with modern completion ...
# KITE            Child well with modern completion design offs...
# SWIFT           Exterior well on a 2-well pad with modern com...
# SPARROW         Exterior well on a 2-well pad with modern com...
# LARK            Exterior well on a 3-well pad with modern com...
# CARDINAL        Exterior well on a 3-well pad with modern com...
# JAY             Interior well on a 3-well pad with modern com...
# CROW            Child well that was codeveloped with adjacent...
# LORIKEET                             SNG; Unbounded legacy well
# MYNAH           CCD; Modern completions infilled between lega...
# PARTRIDGE       CCD; Modern completions infilled between lega...
# CASSOWARY       PDB; CLS parent later offset by modern comple...
# ORIOLE          CCD; Modern 3 well development infilled betwe...
# WARBLER         CLD; Modern 3 well development infilled betwe...
# HARPY           CCD; Modern 3 well development infilled betwe...
# BEE-EATER       CCD; Modern completion comparison for twin pa...
# LOON              CLS; Wider CS & increase #/cl completion test
# CUCKOO                                        SNG; Bossier well
# ROOSTER                      CLS; Increase #/cl completion test
# ARCHAEOPTERYX   CCD; Modern completions infilled between lega...
# TERN            CCD; Modern completions infilled between lega...
# STILT           CCD; Modern completions infilled between lega...
# AVOCET          CCD; Modern completions infilled between lega...
# OSTRICH         CLUSTER UNBOUND; Clean data, data suggest lar...
# EMU                     CLUSTER BOUND; Modern Completion design
# DUCK            PARENT; Modern Completion design, high IP, cl...
# HERON           CLUSTER BOUND; co-developed, single bounded d...
# STORK                     CHILD BOUND; double bounded depletion
# SWAN            CHILD BOUND; co-developed, single bound deple...
# PARROT                       PARENT; co-developed, no depletion
# CRANE           CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# IBIS            CLUSTER UNBOUND; co-devoloped, 830' inner-wel...
# EGRET                       unbounded; Largest CUM in Marcellus
# PHEASANT        SINGLE; Modern Completion design, high Ark an...
# MACAW                        1500' innerwell unbounded exterior
# FLAMINGO                     1500' innerwell unbounded exterior
# PEACOCK                      1500' innerwell unbounded exterior
# PENGUIN                      1500' innerwell unbounded exterior
# ALBATROSS                                             Unbounded
# PELICAN                      1200' innerwell unbounded exterior
# OWL                          1200' innerwell unbounded exterior
# FINCH                                                     1700'
# ROBIN                                                     1700'
# BLUEBIRD                     1500' innerwell unbounded exterior
# CANARY                       1500' innerwell unbounded exterior
# SEAGULL                      1300' innerwell unbounded exterior
# HUMMINGBIRD                  1300' innerwell unbounded exterior
# PHOENIX                       900' innerwell unbounded exterior
# TOUCAN                        900' innerwell unbounded exterior
# GOOSE                                                 Unbounded

# %%
well_data.State.unique()
# Out:
# array(['TX', 'LA', 'PA'], dtype=object)

# %%
well_data.groupby(['State', 'Formation/Reservoir']).agg({' Description ': 'count'})
# Out:
#                             Description
# State Formation/Reservoir
# LA    BOSSIER SHALE                    1
#       HAYNESVILLE SHALE               14
# PA    MARCELLUS                       11
#       MARCELLUS - UPPER               16
# TX    EAGLE FORD                      11

# %% [markdown]
# Два штата расположены рядом, третий - на другом конце страны, но пласты во всех штатах разные, поэтому столбец "Штат" можно не использовать, т.к. это административное понятие, а пласт - геологическое.

# %% [markdown]
# Следующие 3 колонки - переводим в количественные.

# %%
well_data[' Spacing '].unique()
# Out:
# array(['1400', '1000', 'Unbounded', '1500', '800', '700', '1300', nan,
#        '850', '1050', '1250', '1850', '1650', '830', '1800', '1200',
#        '1700', '900'], dtype=object)

# %% [markdown]
# Spacing обычно измеряют в единицах площади на каждую скважину. Unbounded - одна скважина без соседей, т.е. "бесконечность". Преобразую в обратную величину - число скважин на единицу площади.

# %%
well_data['inverse_spacing'] = well_data[' Spacing ']\
    .replace(to_replace='Unbounded', value=np.inf)\
    .astype('float')\
    .apply(lambda x: 1/x)

# %% [markdown]
# В двух других колонках у некоторых значений есть разделитель разрядов ",".

# %%
well_data[['# of Total Proppant (Lbs)', 'Total Fluid (Bbls)']] = well_data[['# of Total Proppant (Lbs)', 'Total Fluid (Bbls)']]\
    .replace(to_replace=r',', value='', regex=True)\
    .astype('float')

# %% [markdown]
# Изучаю описание

# %%
well_data[' Description '].to_list()
# Out:
# [' Well began producing and was later recompleted with modern completion design. ',
#  ' Interior well on a 3-well pad that was shut-in due to market conditions. Interpreted well response showed increased productivity post shut-in period. ',
#  ' Exterior well on a 3-well pad that was shut-in due to market conditions. Interpreted well response showed decreased productivity post shut-in period. ',
#  ' Single unbounded well with modern completion design. ',
#  ' Child well with modern completion design offsetting parent well with legacy completion design. ',
#  ' Exterior well on a 2-well pad with modern completion design. ',
#  ' Exterior well on a 2-well pad with modern completion design. ',
#  ' Exterior well on a 3-well pad with modern completion design. ',
#  ' Exterior well on a 3-well pad with modern completion design. ',
#  ' Interior well on a 3-well pad with modern completion design. ',
#  ' Child well that was codeveloped with adjacent well on a 2-well pad. Well was shut-in due to market conditions. Interpreted well response showed equivalent productivity post shut-in period. ',
#  '\xa0SNG; Unbounded legacy well\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0PDB; CLS parent later offset by modern completion\xa0',
#  '\xa0CCD; Modern 3 well development infilled between legacy parent wells.\xa0',
#  '\xa0CLD; Modern 3 well development infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern 3 well development infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern completion comparison for twin pair test.\xa0',
#  '\xa0CLS; Wider CS & increase #/cl completion test\xa0',
#  '\xa0SNG; Bossier well\xa0',
#  '\xa0CLS; Increase #/cl completion test\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0CCD; Modern completions infilled between legacy parent wells.\xa0',
#  '\xa0CLUSTER UNBOUND; Clean data, data suggest large drainage area, located in key Tier development Area\xa0',
#  '\xa0CLUSTER BOUND; Modern Completion design\xa0',
#  '\xa0PARENT; Modern Completion design, high IP, clean data, small portion depleted\xa0',
#  '\xa0CLUSTER BOUND; co-developed, single bounded depletion\xa0',
#  '\xa0CHILD BOUND; double bounded depletion\xa0',
#  '\xa0CHILD BOUND; co-developed, single bound depletion\xa0',
#  '\xa0PARENT; co-developed, no depletion\xa0',
#  "\xa0CLUSTER UNBOUND; co-devoloped, 830' inner-well spacing, modelling shows greater than 1000' ; unbounded to east\xa0",
#  "\xa0CLUSTER UNBOUND; co-devoloped, 830' inner-well spacing, modelling shows greater than 1000' ; unbounded to east\xa0",
#  '\xa0unbounded; Largest CUM in Marcellus\xa0',
#  '\xa0SINGLE; Modern Completion design, high Ark and clean data\xa0',
#  "\xa01500' innerwell unbounded exterior\xa0",
#  "\xa01500' innerwell unbounded exterior\xa0",
#  "\xa01500' innerwell unbounded exterior\xa0",
#  "\xa01500' innerwell unbounded exterior\xa0",
#  '\xa0Unbounded\xa0',
#  "\xa01200' innerwell unbounded exterior\xa0",
#  "\xa01200' innerwell unbounded exterior\xa0",
#  "\xa01700'\xa0",
#  "\xa01700'\xa0",
#  "\xa01500' innerwell unbounded exterior\xa0",
#  "\xa01500' innerwell unbounded exterior\xa0",
#  "\xa01300' innerwell unbounded exterior\xa0",
#  "\xa01300' innerwell unbounded exterior\xa0",
#  "\xa0900' innerwell unbounded exterior\xa0",
#  "\xa0900' innerwell unbounded exterior\xa0",
#  '\xa0Unbounded\xa0']

# %% [markdown]
# ### _У первых трех скважин сложная история: у первой выполняли повторное заканчивание, у второй и третьей был длительный простой. Учесть при обработке данных по добыче._

# %%
well_data[' Configuration '].unique()
# Out:
# array([' Initial Config ', '\xa0Initial Config\xa0'], dtype=object)

# %% [markdown]
# По сути, одно значение. Эту и следующие колонки в данной версии не использую.Также не использую номер скважины, т.к. индентификация в других таблицах по названию.

# %%
well_data.drop(columns=['Well Number', 'State', ' Spacing ', ' Configuration ',
       'Production Path', 'Pressure Loss Correlation', 'Production Path.1',
       'Pressure Loss Correlation.1', 'Production Path.2',
       'Pressure Loss Correlation.2', 'Production Path.3',
       'Pressure Loss Correlation.3', 'Production Path.4',
       'Pressure Loss Correlation.4', ' Description '], inplace=True)

# %% [markdown]
# ## Количественные переменные

# %%
well_data.columns
# Out:
# Index(['Formation/Reservoir', ' Initial Pressure Estimate (psi) ',
#        ' Reservoir Temperature (deg F) ', ' Net Pay (ft) ',
#        ' Wellbore Diameter (ft) ', 'Porosity', ' Water Saturation ',
#        ' Oil Saturation ', ' Gas Saturation ', ' Gas Specific Gravity ', 'CO2',
#        ' H2S ', 'N2', 'Condensate Yield (Bc/MMcf)', 'Condensate Gravity (API)',
#        ' Dew Point Pressure (psi) ', 'Sep. Temperature (deg F)',
#        'Sep. Pressure (psi)', ' Oil Gravity (API) ', ' Initial GOR (scf/bbl) ',
#        ' Bubble Point Pressure (psi) ', ' TVD (ft) ', '# Stages',
#        '# Clusters ', '# Clusters per Stage', 'Pre-Refrac Completion # Stages',
#        'Pre-Refrac Completion # Clusters ',
#        'Initian Completion # Clusters per Stage', '# of Total Proppant (Lbs)',
#        'Total Fluid (Bbls)', ' Lateral Length (ft) ', ' Top Perf (ft) ',
#        ' Bottom Perf (ft) ', ' Sandface Temp (deg F) ',
#        ' Static Wellhead Temp (deg F) ', ' Tubing ID (in) ',
#        ' Tubing OD (in) ', ' Tubing Depth (ft) ', ' Casing ID 1 (in) ',
#        ' Casing Footage 1 (ft) ', ' Casing ID 2 (in) ',
#        ' Casing Footage 2 (ft) ', ' Casing Depth (ft) ',
#        ' Configuration Change (Days Since First Prod) ', ' Tubing ID (in) .1',
#        ' Tubing OD (in) .1', ' Tubing Depth (ft) .1', ' Casing ID 1 (in) .1',
#        ' Casing Footage 1 (ft) .1', ' Casing ID 2 (in) .1',
#        ' Casing Footage 2 (ft) .1', ' Casing Depth (ft) .1',
#        ' Configuration Change (Days Since First Prod) .1',
#        ' Tubing ID (in) .2', ' Tubing OD (in) .2', ' Tubing Depth (ft) .2',
#        ' Casing ID 1 (in) .2', ' Casing Footage 1 (ft) .2',
#        ' Casing ID 2 (in) .2', ' Casing Footage 2 (ft) .2',
#        ' Casing Depth (ft) .2',
#        ' Configuration Change (Days Since First Prod) .2',
#        ' Tubing ID (in) .3', ' Tubing OD (in) .3', ' Tubing Depth (ft) .3',
#        ' Casing ID 1 (in) .3', ' Casing Footage 1 (ft) .3',
#        ' Casing ID 2 (in) .3', ' Casing Footage 2 (ft) .3',
#        ' Casing Depth (ft) .3',
#        ' Configuration Change (Days Since First Prod) .3',
#        ' Tubing ID (in) .4', ' Tubing OD (in) .4', ' Tubing Depth (ft) .4',
#        ' Casing ID 1 (in) .4', ' Casing Footage 1 (ft) .4',
#        ' Casing ID 2 (in) .4', ' Casing Footage 2 (ft) .4',
#        ' Casing Depth (ft) .4', 'inverse_spacing'],
#       dtype='object')

# %%
well_data[' Configuration Change (Days Since First Prod) '].unique()
# Out:
# array([ 64.,  61.,  40., 205., 111., 144., 156., 122., 119., 132.,  24.,
#         50.,  nan, 429., 431., 426., 236., 421., 424., 381., 306., 305.])

# %%
well_data[' Configuration Change (Days Since First Prod) .1'].unique()
# Out:
# array([1101.,  123.,  125.,   nan,  896.,  887.,  438.,  486.,  480.,
#         216.])

# %%
well_data[' Configuration Change (Days Since First Prod) .2'].unique()
# Out:
# array([1302.,  196.,  233.,   nan,  248.])

# %%
well_data[' Configuration Change (Days Since First Prod) .3'].unique()
# Out:
# array([1602.,   nan])

# %% [markdown]
# Были изменения конструкции скважин.

# %%
well_data[[' Configuration Change (Days Since First Prod) ',
           ' Configuration Change (Days Since First Prod) .1',
          ' Configuration Change (Days Since First Prod) .2',
          ' Configuration Change (Days Since First Prod) .3']]\
                .dropna(how='all')
# Out:
#            Configuration Change (Days Since First Prod)   \
# OSPREY                                              64.0
# FALCON                                              61.0
# HAWK                                                40.0
# EAGLE                                              205.0
# KITE                                               111.0
# SWIFT                                              144.0
# SPARROW                                            156.0
# LARK                                               122.0
# CARDINAL                                           119.0
# JAY                                                132.0
# CROW                                                24.0
# LORIKEET                                            50.0
# ORIOLE                                             429.0
# WARBLER                                            429.0
# HARPY                                              431.0
# CUCKOO                                             426.0
# EMU                                                236.0
# PELICAN                                            421.0
# OWL                                                424.0
# BLUEBIRD                                           381.0
# CANARY                                             381.0
# PHOENIX                                            306.0
# TOUCAN                                             305.0
#
#            Configuration Change (Days Since First Prod) .1  \
# OSPREY                                              1101.0
# FALCON                                               123.0
# HAWK                                                 125.0
# EAGLE                                                  NaN
# KITE                                                   NaN
# SWIFT                                                896.0
# SPARROW                                              887.0
# LARK                                                 438.0
# CARDINAL                                             486.0
# JAY                                                  480.0
# CROW                                                 216.0
# LORIKEET                                               NaN
# ORIOLE                                                 NaN
# WARBLER                                                NaN
# HARPY                                                  NaN
# CUCKOO                                                 NaN
# EMU                                                    NaN
# PELICAN                                                NaN
# OWL                                                    NaN
# BLUEBIRD                                               NaN
# CANARY                                                 NaN
# PHOENIX                                                NaN
# TOUCAN                                                 NaN
#
#            Configuration Change (Days Since First Prod) .2  \
# OSPREY                                              1302.0
# FALCON                                               196.0
# HAWK                                                 233.0
# EAGLE                                                  NaN
# KITE                                                   NaN
# SWIFT                                                  NaN
# SPARROW                                                NaN
# LARK                                                   NaN
# CARDINAL                                               NaN
# JAY                                                    NaN
# CROW                                                 248.0
# LORIKEET                                               NaN
# ORIOLE                                                 NaN
# WARBLER                                                NaN
# HARPY                                                  NaN
# CUCKOO                                                 NaN
# EMU                                                    NaN
# PELICAN                                                NaN
# OWL                                                    NaN
# BLUEBIRD                                               NaN
# CANARY                                                 NaN
# PHOENIX                                                NaN
# TOUCAN                                                 NaN
#
#            Configuration Change (Days Since First Prod) .3
# OSPREY                                              1602.0
# FALCON                                                 NaN
# HAWK                                                   NaN
# EAGLE                                                  NaN
# KITE                                                   NaN
# SWIFT                                                  NaN
# SPARROW                                                NaN
# LARK                                                   NaN
# CARDINAL                                               NaN
# JAY                                                    NaN
# CROW                                                   NaN
# LORIKEET                                               NaN
# ORIOLE                                                 NaN
# WARBLER                                                NaN
# HARPY                                                  NaN
# CUCKOO                                                 NaN
# EMU                                                    NaN
# PELICAN                                                NaN
# OWL                                                    NaN
# BLUEBIRD                                               NaN
# CANARY                                                 NaN
# PHOENIX                                                NaN
# TOUCAN                                                 NaN

# %% [markdown]
# ### _Видно, что изменений было больше трех. Учесть при обработке данных по добыче._

# %% [markdown]
# # Данные по добыче

# %%
production_data = pd.read_csv('production_data.csv', index_col='Lease'); production_data
# Out:
#         Time (Days)  Choke Size  Gas Volume (MMscf)  Oil Volume (stb)  \
# Lease
# OSPREY          1.0         NaN               0.145            504.39
# OSPREY          2.0         NaN               0.186            564.76
# OSPREY          3.0         NaN               0.231            653.51
# OSPREY          4.0         NaN               0.268            740.71
# OSPREY          5.0         NaN               0.261            678.06
# ...             ...         ...                 ...               ...
# GOOSE        2842.0         NaN               0.000              0.00
# GOOSE        2843.0         NaN               0.000              0.00
# GOOSE        2844.0         NaN               0.000              0.00
# GOOSE        2845.0         NaN               0.000              0.00
# GOOSE        2846.0         NaN               0.000              0.00
#
#         Water Volume  (stb)  Gas Lift Inj Volume  (MMscf)  \
# Lease
# OSPREY                718.0                           NaN
# OSPREY                922.0                           NaN
# OSPREY                753.0                           NaN
# OSPREY                700.0                           NaN
# OSPREY                530.0                           NaN
# ...                     ...                           ...
# GOOSE                   0.0                           NaN
# GOOSE                   0.0                           NaN
# GOOSE                   0.0                           NaN
# GOOSE                   0.0                           NaN
# GOOSE                   0.0                           NaN
#
#         Casing Pressure  (psi(a))  Tubing Pressure  (psi(a))  \
# Lease
# OSPREY                2064.695943                  14.695943
# OSPREY                1989.695943                  14.695943
# OSPREY                1864.695943                  14.695943
# OSPREY                1814.695943                  14.695943
# OSPREY                1714.695943                  14.695943
# ...                           ...                        ...
# GOOSE                 1724.502000                  -0.755000
# GOOSE                 1723.853000                  -0.111000
# GOOSE                 1723.499000                  -0.398000
# GOOSE                 1722.222000                  -0.555000
# GOOSE                 1722.120000                  -0.115000
#
#         Active Pressure  (psi(a))  Line Pressure  (psi(a)) Pressure Source   \
# Lease
# OSPREY                2064.695943                14.695943  Casing Pressure
# OSPREY                1989.695943                14.695943  Casing Pressure
# OSPREY                1864.695943                14.695943  Casing Pressure
# OSPREY                1814.695943                14.695943  Casing Pressure
# OSPREY                1714.695943                14.695943  Casing Pressure
# ...                           ...                      ...              ...
# GOOSE                   -0.755000                 1.723000  Tubing Pressure
# GOOSE                   -0.111000                 2.343000  Tubing Pressure
# GOOSE                   -0.398000                 1.099000  Tubing Pressure
# GOOSE                   -0.555000                 0.633000  Tubing Pressure
# GOOSE                   -0.115000                 0.626000  Tubing Pressure
#
#         Calculated Sandface Pressure  (psi(a))
# Lease
# OSPREY                             5050.159793
# OSPREY                             5009.599839
# OSPREY                             4795.991972
# OSPREY                             4696.626023
# OSPREY                             4546.990059
# ...                                        ...
# GOOSE                                      NaN
# GOOSE                                      NaN
# GOOSE                                      NaN
# GOOSE                                      NaN
# GOOSE                                      NaN
#
# [60967 rows x 12 columns]

# %% [markdown]
# Целевые переменные: дебит газа и нефти. Дебит воды - также целевая переменная, но нежелательная, т.к. негативно влияет на экономику.

# %% [markdown]
# Временные интервалы для разных скважин разные:

# %%
production_data.groupby(level=0).agg({'Time (Days)': 'max'})
# Out:
#                Time (Days)
# Lease
# ALBATROSS          893.000
# ARCHAEOPTERYX      856.000
# AVOCET             508.000
# BEE-EATER          417.000
# BLUEBIRD          1123.000
# CANARY            1123.000
# CARDINAL           781.000
# CASSOWARY         2393.000
# CRANE             2190.000
# CROW               345.000
# CUCKOO            1033.000
# DUCK              1156.000
# EAGLE             1483.000
# EGRET             3692.000
# EMU               1076.000
# FALCON             249.625
# FINCH             1738.000
# FLAMINGO           541.000
# GOOSE             2846.000
# HARPY              925.000
# HAWK               249.375
# HERON              636.000
# HUMMINGBIRD        508.000
# IBIS              2190.000
# JAY                782.000
# KITE              1066.000
# LARK               783.000
# LOON               417.000
# LORIKEET          4031.000
# MACAW              541.000
# MYNAH              589.000
# ORIOLE             925.000
# OSPREY            2355.000
# OSTRICH           3158.000
# OWL                898.000
# PARROT             636.000
# PARTRIDGE          589.000
# PEACOCK            601.000
# PELICAN            898.000
# PENGUIN            601.000
# PHEASANT           771.000
# PHOENIX            501.000
# ROBIN             1729.000
# ROOSTER           1432.000
# SEAGULL            504.000
# SPARROW           1245.000
# STILT              507.000
# STORK              636.000
# SWAN               636.000
# SWIFT             1245.000
# TERN               856.000
# TOUCAN             500.000
# WARBLER            925.000

# %% [markdown]
# Дебит нефти

# %%
fig, ax = plt.subplots(figsize=(15,12))
production_data.groupby(level=0).plot.line(x='Time (Days)', y='Oil Volume (stb)', ax=ax, legend=False);

# %% [markdown]
# Дебит газа

# %%
fig, ax = plt.subplots(figsize=(15,12))
production_data.groupby(level=0).plot.line(x='Time (Days)', y='Gas Volume (MMscf)', ax=ax, legend=False);

# %% [markdown]
# Пример скважины:

# %%
fig, ax = plt.subplots(figsize=(8,6))
production_data.loc['PEACOCK', :].plot.line(x='Time (Days)', y='Gas Volume (MMscf)', ax=ax, legend=False);

# %% [markdown]
# Смотрим, какие скважины давали только газ или только нефть.

# %%
production_data.groupby(level=0)\
    .agg({'Gas Volume (MMscf)': 'sum', 'Oil Volume (stb)': 'sum'})
# Out:
#                Gas Volume (MMscf)  Oil Volume (stb)
# Lease
# ALBATROSS             2520.947870          0.000000
# ARCHAEOPTERYX        11694.297790          0.000000
# AVOCET                8602.082260          0.000000
# BEE-EATER            11825.701650          0.000000
# BLUEBIRD              7209.051330          0.000000
# CANARY                7607.488870          0.000000
# CARDINAL               106.091600     115249.591600
# CASSOWARY             5817.028610          0.000000
# CRANE                14192.400230          0.000000
# CROW                    91.475570     128589.460000
# CUCKOO               10090.657210          0.000000
# DUCK                 20069.655180          0.000000
# EAGLE                  179.921108     422035.633300
# EGRET                22038.542480          0.000000
# EMU                   9244.322050          0.000000
# FALCON                  25.131393     137556.840000
# FINCH                 9229.600600          0.000000
# FLAMINGO              4129.356030          0.000000
# GOOSE                 4086.560070          0.000000
# HARPY                11519.088500          0.000000
# HAWK                    21.968277     117716.300000
# HERON                 7998.197900          0.000000
# HUMMINGBIRD           4565.134700          0.000000
# IBIS                 14348.130130          0.000000
# JAY                     83.272784      81972.320500
# KITE                    89.526616      77392.514200
# LARK                   135.727615     156762.926000
# LOON                 13877.227630          0.000000
# LORIKEET              2124.331340          0.000000
# MACAW                 4774.527750          0.000000
# MYNAH                 8717.243720          0.000000
# ORIOLE                9758.085790          0.000000
# OSPREY                 104.507032     307404.183852
# OSTRICH               8358.232340          0.000000
# OWL                   2777.713610          0.000000
# PARROT               12563.576580          0.000000
# PARTRIDGE             8237.107620          0.000000
# PEACOCK               7928.759880          0.000000
# PELICAN               2602.984280          0.000000
# PENGUIN               5539.480590          0.000000
# PHEASANT             13245.631700          0.000000
# PHOENIX               2747.872360          0.000000
# ROBIN                 7870.010570          0.000000
# ROOSTER               9823.206330          0.000000
# SEAGULL               7480.721000          0.000000
# SPARROW                127.986170     186464.680200
# STILT                 7564.309530          0.000000
# STORK                 4867.653150          0.000000
# SWAN                 11965.488040          0.000000
# SWIFT                  119.658310     183855.250000
# TERN                 10881.231060          0.000000
# TOUCAN                2599.980600          0.000000
# WARBLER               9237.807300          0.000000

# %% [markdown]
# Газ у всех. Нефтяных мало. Добавляю признак "есть нефть" к описанию скважин.

# %%
oil_producers = production_data.groupby(level=0)\
    .agg({'Oil Volume (stb)': 'sum'})\
    .rename(columns={'Oil Volume (stb)': 'oil_producer'})\
    .apply(lambda x: x != 0.0)

# %%
oil_producers.sum()
# Out:
# oil_producer    11
# dtype: int64

# %% [markdown]
# Всего 11 скважин из 53

# %%
oil_producers_list = well_data.loc[oil_producers.oil_producer, :].index.to_list()
oil_producers_list
# Out:
# ['OSPREY',
#  'FALCON',
#  'HAWK',
#  'EAGLE',
#  'KITE',
#  'SWIFT',
#  'SPARROW',
#  'LARK',
#  'CARDINAL',
#  'JAY',
#  'CROW']

# %%
well_data = well_data.join(oil_producers); well_data
# Out:
#               Formation/Reservoir   Initial Pressure Estimate (psi)   \
# OSPREY                 EAGLE FORD                               5400
# FALCON                 EAGLE FORD                               5700
# HAWK                   EAGLE FORD                               5650
# EAGLE                  EAGLE FORD                               5000
# KITE                   EAGLE FORD                               5000
# SWIFT                  EAGLE FORD                               5164
# SPARROW                EAGLE FORD                               5164
# LARK                   EAGLE FORD                               5700
# CARDINAL               EAGLE FORD                               5900
# JAY                    EAGLE FORD                               5700
# CROW                   EAGLE FORD                               5500
# LORIKEET        HAYNESVILLE SHALE                               9939
# MYNAH           HAYNESVILLE SHALE                               9800
# PARTRIDGE       HAYNESVILLE SHALE                               9900
# CASSOWARY       HAYNESVILLE SHALE                              12223
# ORIOLE          HAYNESVILLE SHALE                              11325
# WARBLER         HAYNESVILLE SHALE                              11000
# HARPY           HAYNESVILLE SHALE                              11325
# BEE-EATER       HAYNESVILLE SHALE                              10000
# LOON            HAYNESVILLE SHALE                              10000
# CUCKOO             BOSSIER SHALE                               10500
# ROOSTER         HAYNESVILLE SHALE                              10500
# ARCHAEOPTERYX   HAYNESVILLE SHALE                              10300
# TERN            HAYNESVILLE SHALE                              10450
# STILT           HAYNESVILLE SHALE                              10800
# AVOCET          HAYNESVILLE SHALE                              11000
# OSTRICH                 MARCELLUS                               3486
# EMU                     MARCELLUS                               5531
# DUCK                    MARCELLUS                               3900
# HERON                   MARCELLUS                               3500
# STORK                   MARCELLUS                               3000
# SWAN                    MARCELLUS                               4500
# PARROT                  MARCELLUS                               4750
# CRANE                   MARCELLUS                               5538
# IBIS                    MARCELLUS                               5508
# EGRET                   MARCELLUS                               5227
# PHEASANT                MARCELLUS                               4450
# MACAW           MARCELLUS - UPPER                               4609
# FLAMINGO        MARCELLUS - UPPER                               4500
# PEACOCK         MARCELLUS - UPPER                               3150
# PENGUIN         MARCELLUS - UPPER                               3400
# ALBATROSS       MARCELLUS - UPPER                               5000
# PELICAN         MARCELLUS - UPPER                               2500
# OWL             MARCELLUS - UPPER                               2200
# FINCH           MARCELLUS - UPPER                               4300
# ROBIN           MARCELLUS - UPPER                               4100
# BLUEBIRD        MARCELLUS - UPPER                               4200
# CANARY          MARCELLUS - UPPER                               4300
# SEAGULL         MARCELLUS - UPPER                               4400
# HUMMINGBIRD     MARCELLUS - UPPER                               4000
# PHOENIX         MARCELLUS - UPPER                               4450
# TOUCAN          MARCELLUS - UPPER                               3900
# GOOSE           MARCELLUS - UPPER                               5200
#
#                 Reservoir Temperature (deg F)    Net Pay (ft)   \
# OSPREY                                     225              78
# FALCON                                     225              66
# HAWK                                       225              67
# EAGLE                                      235              74
# KITE                                       238              56
# SWIFT                                      225              63
# SPARROW                                    225              62
# LARK                                       228              68
# CARDINAL                                   228              67
# JAY                                        228              67
# CROW                                       221              63
# LORIKEET                                   285             268
# MYNAH                                      351             208
# PARTRIDGE                                  351             209
# CASSOWARY                                  331             161
# ORIOLE                                     343             166
# WARBLER                                    335             166
# HARPY                                      343             166
# BEE-EATER                                  379             165
# LOON                                       379             165
# CUCKOO                                     305             150
# ROOSTER                                    350             180
# ARCHAEOPTERYX                              343             183
# TERN                                       329             193
# STILT                                      346             150
# AVOCET                                     348             150
# OSTRICH                                    115             102
# EMU                                        143             132
# DUCK                                       137             134
# HERON                                      133             150
# STORK                                      133             150
# SWAN                                       134             150
# PARROT                                     135             148
# CRANE                                      146             134
# IBIS                                       146             134
# EGRET                                      134             143
# PHEASANT                                   130             142
# MACAW                                      135             164
# FLAMINGO                                   135             164
# PEACOCK                                    125             231
# PENGUIN                                    125             232
# ALBATROSS                                  126             170
# PELICAN                                    136             245
# OWL                                        136             246
# FINCH                                      133             177
# ROBIN                                      133             177
# BLUEBIRD                                   125             241
# CANARY                                     133             241
# SEAGULL                                    136             230
# HUMMINGBIRD                                136             230
# PHOENIX                                    137             232
# TOUCAN                                     137             232
# GOOSE                                      134             223
#
#                 Wellbore Diameter (ft)   Porosity   Water Saturation   \
# OSPREY                              0.7      6.30               26.00
# FALCON                              0.7      6.30               27.00
# HAWK                                0.7      6.30               27.10
# EAGLE                               0.7      6.30               27.00
# KITE                                0.7      5.00               32.10
# SWIFT                               0.7      5.20               33.10
# SPARROW                             0.7      5.20               33.20
# LARK                                0.7      5.20               36.30
# CARDINAL                            0.7      5.20               36.00
# JAY                                 0.7      5.20               36.10
# CROW                                0.7      5.20               32.10
# LORIKEET                            0.7      8.80               18.38
# MYNAH                               0.7      8.84               20.25
# PARTRIDGE                           0.7      8.84               20.25
# CASSOWARY                           0.7      9.10               19.07
# ORIOLE                              0.7      8.56               20.09
# WARBLER                             0.7      8.55               20.09
# HARPY                               0.7      8.56               20.09
# BEE-EATER                           0.7      9.10               20.00
# LOON                                0.7      9.10               20.00
# CUCKOO                              0.7     10.00               20.00
# ROOSTER                             0.7      8.00               20.00
# ARCHAEOPTERYX                       0.7      8.61               21.00
# TERN                                0.7      8.61               21.00
# STILT                               0.7      8.39               22.90
# AVOCET                              0.7      8.39               22.90
# OSTRICH                             0.7      7.00               32.97
# EMU                                 0.7      6.35               19.60
# DUCK                                0.7      6.94               31.59
# HERON                               0.7      7.44               22.94
# STORK                               0.7      7.49               21.03
# SWAN                                0.7      7.11               31.08
# PARROT                              0.7      7.08               30.93
# CRANE                               0.7      6.36               34.84
# IBIS                                0.7      6.37               34.89
# EGRET                               0.7      8.11               43.59
# PHEASANT                            0.7      7.86               39.28
# MACAW                               0.7      6.52               27.00
# FLAMINGO                            0.7      6.52               27.00
# PEACOCK                             0.7      6.75               27.00
# PENGUIN                             0.7      6.72               26.00
# ALBATROSS                           0.7      6.39               38.00
# PELICAN                             0.7      5.31               40.00
# OWL                                 0.7      5.29               39.00
# FINCH                               0.7      7.23               41.29
# ROBIN                               0.7      7.23               41.28
# BLUEBIRD                            0.7      6.03               35.00
# CANARY                              0.7      6.03               35.00
# SEAGULL                             0.7      5.99               43.00
# HUMMINGBIRD                         0.7      5.99               43.00
# PHOENIX                             0.7      5.87               47.00
# TOUCAN                              0.7      5.87               47.00
# GOOSE                               0.7      6.17               40.22
#
#                 Oil Saturation    Gas Saturation    Gas Specific Gravity   \
# OSPREY                    74.00              0.00                  0.9513
# FALCON                    73.00              0.00                  0.9936
# HAWK                      72.90              0.00                  0.9936
# EAGLE                     73.00              0.00                  0.9200
# KITE                      67.90              0.00                  0.7200
# SWIFT                     66.90              0.00                  0.6500
# SPARROW                   66.80              0.00                  0.6500
# LARK                      63.70              0.00                  0.9000
# CARDINAL                  64.00              0.00                  0.9000
# JAY                       60.20              3.70                  0.6500
# CROW                      67.90              0.00                  0.9000
# LORIKEET                   0.00             81.62                  0.5800
# MYNAH                      0.00             79.75                  0.5820
# PARTRIDGE                  0.00             79.75                  0.5830
# CASSOWARY                  0.00             80.93                  0.5800
# ORIOLE                     0.00             79.91                  0.5930
# WARBLER                    0.00             79.91                  0.5930
# HARPY                      0.00             79.91                  0.5930
# BEE-EATER                  0.00             80.00                  0.5890
# LOON                       0.00             80.00                  0.5890
# CUCKOO                     0.00             80.00                  0.6050
# ROOSTER                    0.00             80.00                  0.6120
# ARCHAEOPTERYX              0.00             79.00                  0.5950
# TERN                       0.00             79.00                  0.5940
# STILT                      0.00             77.10                  0.5970
# AVOCET                     0.00             77.10                  0.5980
# OSTRICH                    0.13             66.90                  0.5700
# EMU                        0.00             80.40                  0.5700
# DUCK                       0.00             68.41                  0.5700
# HERON                      0.00             77.06                  0.5700
# STORK                      0.00             78.97                  0.5700
# SWAN                       0.00             68.92                  0.5700
# PARROT                     0.00             69.07                  0.5700
# CRANE                      0.00             65.16                  0.5700
# IBIS                       0.00             65.11                  0.5700
# EGRET                      0.00             56.41                  0.5700
# PHEASANT                   0.00             60.72                  0.5700
# MACAW                      0.00             73.00                  0.5700
# FLAMINGO                   0.00             73.00                  0.5700
# PEACOCK                    0.00             73.00                  0.5700
# PENGUIN                    0.00             74.00                  0.5700
# ALBATROSS                  0.00             62.00                  0.5700
# PELICAN                    0.00             60.00                  0.5700
# OWL                        0.00             61.00                  0.5700
# FINCH                      0.00             58.71                  0.5700
# ROBIN                      0.00             58.72                  0.5700
# BLUEBIRD                   0.00             65.00                  0.5700
# CANARY                     0.00             65.00                  0.5700
# SEAGULL                    0.00             57.00                  0.5700
# HUMMINGBIRD                0.00             57.00                  0.5700
# PHOENIX                    0.00             53.00                  0.5700
# TOUCAN                     0.00             53.00                  0.5700
# GOOSE                      0.00             59.78                  0.5700
#
#                ...   Tubing ID (in) .4   Tubing OD (in) .4  \
# OSPREY         ...               2.441               2.875
# FALCON         ...                 NaN                 NaN
# HAWK           ...                 NaN                 NaN
# EAGLE          ...                 NaN                 NaN
# KITE           ...                 NaN                 NaN
# SWIFT          ...                 NaN                 NaN
# SPARROW        ...                 NaN                 NaN
# LARK           ...                 NaN                 NaN
# CARDINAL       ...                 NaN                 NaN
# JAY            ...                 NaN                 NaN
# CROW           ...                 NaN                 NaN
# LORIKEET       ...                 NaN                 NaN
# MYNAH          ...                 NaN                 NaN
# PARTRIDGE      ...                 NaN                 NaN
# CASSOWARY      ...                 NaN                 NaN
# ORIOLE         ...                 NaN                 NaN
# WARBLER        ...                 NaN                 NaN
# HARPY          ...                 NaN                 NaN
# BEE-EATER      ...                 NaN                 NaN
# LOON           ...                 NaN                 NaN
# CUCKOO         ...                 NaN                 NaN
# ROOSTER        ...                 NaN                 NaN
# ARCHAEOPTERYX  ...                 NaN                 NaN
# TERN           ...                 NaN                 NaN
# STILT          ...                 NaN                 NaN
# AVOCET         ...                 NaN                 NaN
# OSTRICH        ...                 NaN                 NaN
# EMU            ...                 NaN                 NaN
# DUCK           ...                 NaN                 NaN
# HERON          ...                 NaN                 NaN
# STORK          ...                 NaN                 NaN
# SWAN           ...                 NaN                 NaN
# PARROT         ...                 NaN                 NaN
# CRANE          ...                 NaN                 NaN
# IBIS           ...                 NaN                 NaN
# EGRET          ...                 NaN                 NaN
# PHEASANT       ...                 NaN                 NaN
# MACAW          ...                 NaN                 NaN
# FLAMINGO       ...                 NaN                 NaN
# PEACOCK        ...                 NaN                 NaN
# PENGUIN        ...                 NaN                 NaN
# ALBATROSS      ...                 NaN                 NaN
# PELICAN        ...                 NaN                 NaN
# OWL            ...                 NaN                 NaN
# FINCH          ...                 NaN                 NaN
# ROBIN          ...                 NaN                 NaN
# BLUEBIRD       ...                 NaN                 NaN
# CANARY         ...                 NaN                 NaN
# SEAGULL        ...                 NaN                 NaN
# HUMMINGBIRD    ...                 NaN                 NaN
# PHOENIX        ...                 NaN                 NaN
# TOUCAN         ...                 NaN                 NaN
# GOOSE          ...                 NaN                 NaN
#
#                 Tubing Depth (ft) .4   Casing ID 1 (in) .4  \
# OSPREY                        6764.0                  4.67
# FALCON                           NaN                   NaN
# HAWK                             NaN                   NaN
# EAGLE                            NaN                   NaN
# KITE                             NaN                   NaN
# SWIFT                            NaN                   NaN
# SPARROW                          NaN                   NaN
# LARK                             NaN                   NaN
# CARDINAL                         NaN                   NaN
# JAY                              NaN                   NaN
# CROW                             NaN                   NaN
# LORIKEET                         NaN                   NaN
# MYNAH                            NaN                   NaN
# PARTRIDGE                        NaN                   NaN
# CASSOWARY                        NaN                   NaN
# ORIOLE                           NaN                   NaN
# WARBLER                          NaN                   NaN
# HARPY                            NaN                   NaN
# BEE-EATER                        NaN                   NaN
# LOON                             NaN                   NaN
# CUCKOO                           NaN                   NaN
# ROOSTER                          NaN                   NaN
# ARCHAEOPTERYX                    NaN                   NaN
# TERN                             NaN                   NaN
# STILT                            NaN                   NaN
# AVOCET                           NaN                   NaN
# OSTRICH                          NaN                   NaN
# EMU                              NaN                   NaN
# DUCK                             NaN                   NaN
# HERON                            NaN                   NaN
# STORK                            NaN                   NaN
# SWAN                             NaN                   NaN
# PARROT                           NaN                   NaN
# CRANE                            NaN                   NaN
# IBIS                             NaN                   NaN
# EGRET                            NaN                   NaN
# PHEASANT                         NaN                   NaN
# MACAW                            NaN                   NaN
# FLAMINGO                         NaN                   NaN
# PEACOCK                          NaN                   NaN
# PENGUIN                          NaN                   NaN
# ALBATROSS                        NaN                   NaN
# PELICAN                          NaN                   NaN
# OWL                              NaN                   NaN
# FINCH                            NaN                   NaN
# ROBIN                            NaN                   NaN
# BLUEBIRD                         NaN                   NaN
# CANARY                           NaN                   NaN
# SEAGULL                          NaN                   NaN
# HUMMINGBIRD                      NaN                   NaN
# PHOENIX                          NaN                   NaN
# TOUCAN                           NaN                   NaN
# GOOSE                            NaN                   NaN
#
#                 Casing Footage 1 (ft) .4   Casing ID 2 (in) .4  \
# OSPREY                            6941.0                 2.992
# FALCON                               NaN                   NaN
# HAWK                                 NaN                   NaN
# EAGLE                                NaN                   NaN
# KITE                                 NaN                   NaN
# SWIFT                                NaN                   NaN
# SPARROW                              NaN                   NaN
# LARK                                 NaN                   NaN
# CARDINAL                             NaN                   NaN
# JAY                                  NaN                   NaN
# CROW                                 NaN                   NaN
# LORIKEET                             NaN                   NaN
# MYNAH                                NaN                   NaN
# PARTRIDGE                            NaN                   NaN
# CASSOWARY                            NaN                   NaN
# ORIOLE                               NaN                   NaN
# WARBLER                              NaN                   NaN
# HARPY                                NaN                   NaN
# BEE-EATER                            NaN                   NaN
# LOON                                 NaN                   NaN
# CUCKOO                               NaN                   NaN
# ROOSTER                              NaN                   NaN
# ARCHAEOPTERYX                        NaN                   NaN
# TERN                                 NaN                   NaN
# STILT                                NaN                   NaN
# AVOCET                               NaN                   NaN
# OSTRICH                              NaN                   NaN
# EMU                                  NaN                   NaN
# DUCK                                 NaN                   NaN
# HERON                                NaN                   NaN
# STORK                                NaN                   NaN
# SWAN                                 NaN                   NaN
# PARROT                               NaN                   NaN
# CRANE                                NaN                   NaN
# IBIS                                 NaN                   NaN
# EGRET                                NaN                   NaN
# PHEASANT                             NaN                   NaN
# MACAW                                NaN                   NaN
# FLAMINGO                             NaN                   NaN
# PEACOCK                              NaN                   NaN
# PENGUIN                              NaN                   NaN
# ALBATROSS                            NaN                   NaN
# PELICAN                              NaN                   NaN
# OWL                                  NaN                   NaN
# FINCH                                NaN                   NaN
# ROBIN                                NaN                   NaN
# BLUEBIRD                             NaN                   NaN
# CANARY                               NaN                   NaN
# SEAGULL                              NaN                   NaN
# HUMMINGBIRD                          NaN                   NaN
# PHOENIX                              NaN                   NaN
# TOUCAN                               NaN                   NaN
# GOOSE                                NaN                   NaN
#
#                 Casing Footage 2 (ft) .4   Casing Depth (ft) .4  \
# OSPREY                            6307.0                13248.0
# FALCON                               NaN                    NaN
# HAWK                                 NaN                    NaN
# EAGLE                                NaN                    NaN
# KITE                                 NaN                    NaN
# SWIFT                                NaN                    NaN
# SPARROW                              NaN                    NaN
# LARK                                 NaN                    NaN
# CARDINAL                             NaN                    NaN
# JAY                                  NaN                    NaN
# CROW                                 NaN                    NaN
# LORIKEET                             NaN                    NaN
# MYNAH                                NaN                    NaN
# PARTRIDGE                            NaN                    NaN
# CASSOWARY                            NaN                    NaN
# ORIOLE                               NaN                    NaN
# WARBLER                              NaN                    NaN
# HARPY                                NaN                    NaN
# BEE-EATER                            NaN                    NaN
# LOON                                 NaN                    NaN
# CUCKOO                               NaN                    NaN
# ROOSTER                              NaN                    NaN
# ARCHAEOPTERYX                        NaN                    NaN
# TERN                                 NaN                    NaN
# STILT                                NaN                    NaN
# AVOCET                               NaN                    NaN
# OSTRICH                              NaN                    NaN
# EMU                                  NaN                    NaN
# DUCK                                 NaN                    NaN
# HERON                                NaN                    NaN
# STORK                                NaN                    NaN
# SWAN                                 NaN                    NaN
# PARROT                               NaN                    NaN
# CRANE                                NaN                    NaN
# IBIS                                 NaN                    NaN
# EGRET                                NaN                    NaN
# PHEASANT                             NaN                    NaN
# MACAW                                NaN                    NaN
# FLAMINGO                             NaN                    NaN
# PEACOCK                              NaN                    NaN
# PENGUIN                              NaN                    NaN
# ALBATROSS                            NaN                    NaN
# PELICAN                              NaN                    NaN
# OWL                                  NaN                    NaN
# FINCH                                NaN                    NaN
# ROBIN                                NaN                    NaN
# BLUEBIRD                             NaN                    NaN
# CANARY                               NaN                    NaN
# SEAGULL                              NaN                    NaN
# HUMMINGBIRD                          NaN                    NaN
# PHOENIX                              NaN                    NaN
# TOUCAN                               NaN                    NaN
# GOOSE                                NaN                    NaN
#
#                inverse_spacing  oil_producer
# OSPREY                0.000714          True
# FALCON                0.001000          True
# HAWK                  0.001000          True
# EAGLE                 0.000000          True
# KITE                  0.000714          True
# SWIFT                 0.000667          True
# SPARROW               0.000667          True
# LARK                  0.001250          True
# CARDINAL              0.001429          True
# JAY                   0.001429          True
# CROW                  0.000769          True
# LORIKEET                   NaN         False
# MYNAH                 0.001000         False
# PARTRIDGE             0.001000         False
# CASSOWARY             0.000769         False
# ORIOLE                0.001176         False
# WARBLER               0.001176         False
# HARPY                 0.001176         False
# BEE-EATER             0.000952         False
# LOON                  0.000952         False
# CUCKOO                     NaN         False
# ROOSTER               0.000800         False
# ARCHAEOPTERYX         0.000952         False
# TERN                  0.000952         False
# STILT                 0.001176         False
# AVOCET                0.001176         False
# OSTRICH                    NaN         False
# EMU                   0.000541         False
# DUCK                  0.000606         False
# HERON                 0.000667         False
# STORK                 0.000714         False
# SWAN                  0.000769         False
# PARROT                0.000800         False
# CRANE                 0.001205         False
# IBIS                  0.001205         False
# EGRET                      NaN         False
# PHEASANT              0.000556         False
# MACAW                 0.000667         False
# FLAMINGO              0.000667         False
# PEACOCK               0.000667         False
# PENGUIN               0.000667         False
# ALBATROSS                  NaN         False
# PELICAN               0.000833         False
# OWL                   0.000833         False
# FINCH                 0.000588         False
# ROBIN                 0.000588         False
# BLUEBIRD              0.000667         False
# CANARY                0.000667         False
# SEAGULL               0.000769         False
# HUMMINGBIRD           0.000769         False
# PHOENIX               0.001111         False
# TOUCAN                0.001111         False
# GOOSE                      NaN         False
#
# [53 rows x 81 columns]

# %% [markdown]
# ## Скважины со сложной историей

# %% [markdown]
# Отбираем те, у которых было минимум 2 изменения

# %%
well_data[[' Configuration Change (Days Since First Prod) ',
           ' Configuration Change (Days Since First Prod) .1']]\
                .dropna(how='any')
# Out:
#            Configuration Change (Days Since First Prod)   \
# OSPREY                                              64.0
# FALCON                                              61.0
# HAWK                                                40.0
# SWIFT                                              144.0
# SPARROW                                            156.0
# LARK                                               122.0
# CARDINAL                                           119.0
# JAY                                                132.0
# CROW                                                24.0
#
#            Configuration Change (Days Since First Prod) .1
# OSPREY                                              1101.0
# FALCON                                               123.0
# HAWK                                                 125.0
# SWIFT                                                896.0
# SPARROW                                              887.0
# LARK                                                 438.0
# CARDINAL                                             486.0
# JAY                                                  480.0
# CROW                                                 216.0

# %%
wells_w_2changes = well_data[[' Configuration Change (Days Since First Prod) ',
                               ' Configuration Change (Days Since First Prod) .1']]\
                                    .dropna(how='any').index.to_list()
wells_w_2changes
# Out:
# ['OSPREY',
#  'FALCON',
#  'HAWK',
#  'SWIFT',
#  'SPARROW',
#  'LARK',
#  'CARDINAL',
#  'JAY',
#  'CROW']

# %%
for well in wells_w_2changes:
    fig, ax = plt.subplots(figsize=(18,12))
    ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) '], color='r')
    ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) .1'], color='r')
    production_data.loc[well, :].plot.line(x='Time (Days)',
                                               y='Oil Volume (stb)',
                                               ax=ax, 
                                               legend=False,
                                              title='{}. Oil production'.format(well))
    plt.show();
    
    fig, ax = plt.subplots(figsize=(18,12))
    ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) '], color='r')
    ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) .1'], color='r')
    production_data.loc[well, :].plot.line(x='Time (Days)',
                                               y='Gas Volume (MMscf)',
                                               ax=ax, 
                                               legend=False,
                                              title='{}. Gas production'.format(well))
    plt.show();

# %% [markdown]
# Варианты: использовать только интервал между нулевым и первым измененим конструкции или делить на части и использовать каждую часть как отдельную кривую. Интервал до нулевого изменения, как правило, очень короткий и малоинформативный.

# %% [markdown]
# Отбираем скважины, у которых было только 1 изменение

# %%
well_data[[' Configuration Change (Days Since First Prod) ',
           ' Configuration Change (Days Since First Prod) .1']]\
                .dropna(how='all')\
                .loc[well_data[' Configuration Change (Days Since First Prod) .1'].isna()]
# Out:
#            Configuration Change (Days Since First Prod)   \
# EAGLE                                              205.0
# KITE                                               111.0
# LORIKEET                                            50.0
# ORIOLE                                             429.0
# WARBLER                                            429.0
# HARPY                                              431.0
# CUCKOO                                             426.0
# EMU                                                236.0
# PELICAN                                            421.0
# OWL                                                424.0
# BLUEBIRD                                           381.0
# CANARY                                             381.0
# PHOENIX                                            306.0
# TOUCAN                                             305.0
#
#            Configuration Change (Days Since First Prod) .1
# EAGLE                                                  NaN
# KITE                                                   NaN
# LORIKEET                                               NaN
# ORIOLE                                                 NaN
# WARBLER                                                NaN
# HARPY                                                  NaN
# CUCKOO                                                 NaN
# EMU                                                    NaN
# PELICAN                                                NaN
# OWL                                                    NaN
# BLUEBIRD                                               NaN
# CANARY                                                 NaN
# PHOENIX                                                NaN
# TOUCAN                                                 NaN

# %%
wells_w_1change = well_data[[' Configuration Change (Days Since First Prod) ',
                           ' Configuration Change (Days Since First Prod) .1']]\
                                .dropna(how='all')\
                                .loc[well_data[' Configuration Change (Days Since First Prod) .1'].isna()]\
                                        .index\
                                        .to_list()
wells_w_1change
# Out:
# ['EAGLE',
#  'KITE',
#  'LORIKEET',
#  'ORIOLE',
#  'WARBLER',
#  'HARPY',
#  'CUCKOO',
#  'EMU',
#  'PELICAN',
#  'OWL',
#  'BLUEBIRD',
#  'CANARY',
#  'PHOENIX',
#  'TOUCAN']

# %%
for well in wells_w_1change:
    if well in oil_producers_list:
        fig, ax = plt.subplots(figsize=(18,12))
        ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) '], color='r')
        production_data.loc[well, :].plot.line(x='Time (Days)',
                                                   y='Oil Volume (stb)',
                                                   ax=ax, 
                                                   legend=False,
                                                  title='{}. Oil production'.format(well))
        plt.show();
    
    fig, ax = plt.subplots(figsize=(18,12))
    ax.axvline(well_data.loc[well, ' Configuration Change (Days Since First Prod) '], color='r')
    production_data.loc[well, :].plot.line(x='Time (Days)',
                                               y='Gas Volume (MMscf)',
                                               ax=ax, 
                                               legend=False,
                                              title='{}. Gas production'.format(well))
    plt.show();

# %% [markdown]
# Во многих случаях получаем два равноценных интервала (первый даже длиннее), но не во всех. В некоторых первый слишком короткий. Варианты: оставлять только участок после внесения изменений или делить на интервалы и рассматривать их все.

# %% [markdown]
# Возможный вариант: для всех скважин с любым числом изменений делить на интервалы и отбрасывать слишком короткие, допустим менее 100 дней.

# %% [markdown]
# # Инклинометрия

# %%
deviation_survey = pd.read_csv('deviation_survey.csv', index_col='Lease'); deviation_survey
# Out:
#         Measured Depth (ft)  TVD (ft)
# Lease
# OSPREY                  0.0      0.00
# OSPREY                 95.1     95.10
# OSPREY                153.6    153.60
# OSPREY                214.8    214.80
# OSPREY                273.1    273.10
# ...                     ...       ...
# GOOSE               12211.0   7308.58
# GOOSE               12275.0   7309.42
# GOOSE               12338.0   7309.80
# GOOSE               12384.0   7309.41
# GOOSE               12442.0   7308.61
#
# [76984 rows x 2 columns]

# %%
deviation_survey.columns
# Out:
# Index(['Measured Depth (ft)', 'TVD (ft)'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(15,12))
deviation_survey.groupby(level=0).plot.line(x='Measured Depth (ft)', y='TVD (ft)', ax=ax, legend=False);

# %% [markdown]
# У большинства скважин есть горизонтальный участок, но не у всех. При прогнозах можно будет использовать длину горизонтального участка как независимую переменную.

# %%
well_data.to_csv('well_data_modified.csv')

# %% [markdown]
# # Разделение на тренировочную и тестовую выборки - не делал, т.к. нужна доп. обработка

# %% [markdown]
# В идеале нужно было разделять со стратификацией по пластам и типам скважин (чисто газовая или газ с нефтью), но на божерские сланцы пробурена всего одна скважина, использую только тип скважины.

# %% [markdown]
# from sklearn.model_selection import train_test_split

# %% [markdown]
# well_data_train, well_data_test = train_test_split(well_data,
#                                                    test_size=0.2,
#                                                    random_state=8,
#                                                    shuffle=True,
#                                                    stratify=well_data['oil_producer'])

# %% [markdown]
# test_set = well_data_test.index
# train_set = well_data_train.index

# %% [markdown]
# well_data_train.to_csv('well_data_modified_train.csv')
# well_data_test.to_csv('well_data_modified_test.csv')

# %% [markdown]
# production_data.loc[train_set , :].to_csv('production_data_train.csv')

# %% [markdown]
# production_data.loc[test_set , :].to_csv('production_data_test.csv')

# %% [markdown]
# deviation_survey.loc[train_set , :].to_csv('deviation_survey_train.csv')

# %% [markdown]
# deviation_survey.loc[test_set , :].to_csv('deviation_survey_test.csv')
